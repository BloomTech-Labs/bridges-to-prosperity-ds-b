# %%
# # Desired Output Format
# const bridgeSite = {
#   id: 1014107,
#   name: "Buzi",
#   type: "Suspended",
#   stage: "Rejected",
#   subStage: "Technical",
#   individualsDirectlyServed: 0.0,
#   span: "",
#   latitude: -2.42056,
#   longitude: 28.9662,
#   communitiesServed: [
#     {
#       id: 22050101,
#       name: "Agahehe",
#     },
#     {
#       id: 22050102,
#       name: "Kabacuzi",
#     },
#     {
#       id: 22050103,
#       name: "Kamutozo",
#     },
#     {
#       id: 22050104,
#       name: "Kamweko",
#     },
#   ],
# };

# %%
# Imports
import numpy as np
import pandas as pd
from datetime import date
import json

# %%
# Load data
df = pd.read_csv('https://raw.githubusercontent.com/Lambda-School-Labs/Labs25-Bridges_to_Prosperity-TeamB-ds/jakekrafczyk-patch-1/data/edit/B2P_Rwanda_MatchedIds.csv')
df.drop('Unnamed: 0', 1, inplace=True)
df.head(10)
# Out:
#   Country           Province District  ... Sector_ID   Cell_ID  Village_ID
# 0  Rwanda   Western Province   Rusizi  ...    3605.0  360502.0  36050201.0
# 1  Rwanda   Western Province   Rusizi  ...    3605.0  360502.0  36050201.0
# 2  Rwanda  Northern Province  Rulindo  ...    4104.0  410403.0  41040304.0
# 3  Rwanda  Northern Province  Gicumbi  ...    4506.0       NaN         NaN
# 4  Rwanda  Southern Province  Kamonyi  ...    2803.0  280304.0  28030402.0
# 5  Rwanda  Southern Province  Kamonyi  ...    2803.0  280304.0  28030405.0
# 6  Rwanda  Southern Province  Kamonyi  ...    2807.0  280701.0  28070106.0
# 7  Rwanda  Southern Province  Kamonyi  ...    2802.0  280201.0  28020104.0
# 8  Rwanda  Southern Province  Kamonyi  ...    2802.0  280202.0  28020203.0
# 9  Rwanda  Southern Province  Kamonyi  ...    2801.0  280101.0  28010103.0
#
# [10 rows x 28 columns]

# %%
df.dtypes
# Out:
# Country                                object
# Province                               object
# District                               object
# Sector                                 object
# Cell                                   object
# Bridge Site Name                       object
# Project Stage                          object
# Project Sub-Stage                      object
# Project Code                           object
# Bridge Type                            object
# Span (m)                              float64
# GPS (Latitude)                        float64
# GPS (Longitude)                       float64
# Individuals Directly Served           float64
# Form: Form Name                        object
# Community Served 1                     object
# Community Served 2                     object
# Community Served 3                     object
# Community Served 4                     object
# Community Served 5                     object
# CaseSafeID Form                        object
# Bridge Opportunity: Opportunity ID     object
# Village                                object
# Community_served                       object
# Dist_ID                                 int64
# Sector_ID                             float64
# Cell_ID                               float64
# Village_ID                            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                                  0
# Province                                 0
# District                                 0
# Sector                                   0
# Cell                                     6
# Bridge Site Name                         0
# Project Stage                            0
# Project Sub-Stage                       63
# Project Code                             0
# Bridge Type                            166
# Span (m)                                 0
# GPS (Latitude)                           4
# GPS (Longitude)                          4
# Individuals Directly Served              0
# Form: Form Name                          0
# Community Served 1                      90
# Community Served 2                     198
# Community Served 3                     574
# Community Served 4                     795
# Community Served 5                    1027
# CaseSafeID Form                          0
# Bridge Opportunity: Opportunity ID       0
# Village                                 26
# Community_served                         0
# Dist_ID                                  0
# Sector_ID                               30
# Cell_ID                                 67
# Village_ID                             118
# dtype: int64

# %%
# replace NaN
'''
str : ?
int : 0
float : 0
'''

df['Cell'] = df['Cell'].replace(np.nan, '?')
df['Project Sub-Stage'] = df['Project Sub-Stage'].replace(np.nan, '?')
df['Bridge Type'] = df['Bridge Type'].replace(np.nan, '?')
df['GPS (Latitude)'] = df['GPS (Latitude)'].replace(np.nan, 0)
df['GPS (Longitude)'] = df['GPS (Longitude)'].replace(np.nan, 0)
df['Community Served 1'] = df['Community Served 1'].replace(np.nan, '?')
df['Community Served 2'] = df['Community Served 2'].replace(np.nan, '?')
df['Community Served 3'] = df['Community Served 3'].replace(np.nan, '?')
df['Community Served 4'] = df['Community Served 4'].replace(np.nan, '?')
df['Community Served 5'] = df['Community Served 5'].replace(np.nan, '?')
df['Village'] = df['Village'].replace(np.nan, '?')
df['Sector_ID'] = df['Sector_ID'].replace(np.nan, 0)
df['Cell_ID'] = df['Cell_ID'].replace(np.nan, 0)
df['Village_ID'] = df['Village_ID'].replace(np.nan, 0)

df.head()

# %%
df.dtypes
# Out:
# Country                                object
# Province                               object
# District                               object
# Sector                                 object
# Cell                                   object
# Bridge Site Name                       object
# Project Stage                          object
# Project Sub-Stage                      object
# Project Code                           object
# Bridge Type                            object
# Span (m)                              float64
# GPS (Latitude)                        float64
# GPS (Longitude)                       float64
# Individuals Directly Served           float64
# Form: Form Name                        object
# Community Served 1                     object
# Community Served 2                     object
# Community Served 3                     object
# Community Served 4                     object
# Community Served 5                     object
# CaseSafeID Form                        object
# Bridge Opportunity: Opportunity ID     object
# Village                                object
# Community_served                       object
# Dist_ID                                 int64
# Sector_ID                             float64
# Cell_ID                               float64
# Village_ID                            float64
# dtype: object

# %%
# converting dtypes
df['Span (m)'] = df['Span (m)'].astype(int)
df['Individuals Directly Served'] = df['Individuals Directly Served'].astype(int)
df['Dist_ID'] = df['Dist_ID'].astype(int)
df['Sector_ID'] = df['Sector_ID'].astype(int)
df['Cell_ID'] = df['Cell_ID'].astype(int)
df['Village_ID'] = df['Village_ID'].astype(int)
df.head()
# Out:
#   Country           Province District  ... Sector_ID Cell_ID Village_ID
# 0  Rwanda   Western Province   Rusizi  ...      3605  360502   36050201
# 1  Rwanda   Western Province   Rusizi  ...      3605  360502   36050201
# 2  Rwanda  Northern Province  Rulindo  ...      4104  410403   41040304
# 3  Rwanda  Northern Province  Gicumbi  ...      4506       0          0
# 4  Rwanda  Southern Province  Kamonyi  ...      2803  280304   28030402
#
# [5 rows x 28 columns]

# %%
df['Dist_ID'] = df['Dist_ID'].astype(str)
df['Sector_ID'] = df['Sector_ID'].astype(str)
df['Cell_ID'] = df['Cell_ID'].astype(str)
df['Village_ID'] = df['Village_ID'].astype(str)
df.head()
# Out:
#   Country           Province District  ... Sector_ID Cell_ID Village_ID
# 0  Rwanda   Western Province   Rusizi  ...      3605  360502   36050201
# 1  Rwanda   Western Province   Rusizi  ...      3605  360502   36050201
# 2  Rwanda  Northern Province  Rulindo  ...      4104  410403   41040304
# 3  Rwanda  Northern Province  Gicumbi  ...      4506       0          0
# 4  Rwanda  Southern Province  Kamonyi  ...      2803  280304   28030402
#
# [5 rows x 28 columns]

# %%
df['Sector_ID'] = df['Sector_ID'].replace('0', '?')
df['Cell_ID'] = df['Cell_ID'].replace('0', '?')
df['Village_ID'] = df['Village_ID'].replace('0', '?')
df.head(10)
# Out:
#   Country           Province District  ... Sector_ID Cell_ID Village_ID
# 0  Rwanda   Western Province   Rusizi  ...      3605  360502   36050201
# 1  Rwanda   Western Province   Rusizi  ...      3605  360502   36050201
# 2  Rwanda  Northern Province  Rulindo  ...      4104  410403   41040304
# 3  Rwanda  Northern Province  Gicumbi  ...      4506       ?          ?
# 4  Rwanda  Southern Province  Kamonyi  ...      2803  280304   28030402
# 5  Rwanda  Southern Province  Kamonyi  ...      2803  280304   28030405
# 6  Rwanda  Southern Province  Kamonyi  ...      2807  280701   28070106
# 7  Rwanda  Southern Province  Kamonyi  ...      2802  280201   28020104
# 8  Rwanda  Southern Province  Kamonyi  ...      2802  280202   28020203
# 9  Rwanda  Southern Province  Kamonyi  ...      2801  280101   28010103
#
# [10 rows x 28 columns]

# %%
df.dtypes
# Out:
# Country                                object
# Province                               object
# District                               object
# Sector                                 object
# Cell                                   object
# Bridge Site Name                       object
# Project Stage                          object
# Project Sub-Stage                      object
# Project Code                           object
# Bridge Type                            object
# Span (m)                                int64
# GPS (Latitude)                        float64
# GPS (Longitude)                       float64
# Individuals Directly Served             int64
# Form: Form Name                        object
# Community Served 1                     object
# Community Served 2                     object
# Community Served 3                     object
# Community Served 4                     object
# Community Served 5                     object
# CaseSafeID Form                        object
# Bridge Opportunity: Opportunity ID     object
# Village                                object
# Community_served                       object
# Dist_ID                                object
# Sector_ID                              object
# Cell_ID                                object
# Village_ID                             object
# dtype: object

# %%
# reordering df
column_order = ['Country', 'Province', 'District', 'Dist_ID', 'Sector', 'Sector_ID', 
                'Cell', 'Cell_ID', 'Village', 'Village_ID', 'Bridge Site Name', 
                'Project Code', 'Bridge Type', 'Project Stage', 'Project Sub-Stage', 
                'Individuals Directly Served', 'Span (m)', 'GPS (Latitude)', 
                'GPS (Longitude)', 'Community Served 1', 'Community Served 2', 
                'Community Served 3', 'Community Served 4', 'Community Served 5', 
                'Community_served', 'Form: Form Name', 'CaseSafeID Form', 
                'Bridge Opportunity: Opportunity ID']
df_ordered = df.reindex(columns=column_order)
df_ordered.head(10)
# Out:
#   Country  ... Bridge Opportunity: Opportunity ID
# 0  Rwanda  ...                    006f100000d1fk1
# 1  Rwanda  ...                    006f100000d1fjw
# 2  Rwanda  ...                    006f100000a86I3
# 3  Rwanda  ...                    006f100000cPpL8
# 4  Rwanda  ...                    006f100000eescb
# 5  Rwanda  ...                    006f100000eescl
# 6  Rwanda  ...                    006f100000eesdZ
# 7  Rwanda  ...                    006f100000eesdK
# 8  Rwanda  ...                    006f100000eescv
# 9  Rwanda  ...                    006f100000eesdP
#
# [10 rows x 28 columns]

# %%
# Renaming Column
df_ordered = df_ordered.rename(columns = {'Community_served' : 'Communities_Served'})

# %%
df_ordered['Communities_Served'] = df_ordered['Communities_Served'].str.split()

# %%
df_ordered.head()
# Out:
#   Country  ... Bridge Opportunity: Opportunity ID
# 0  Rwanda  ...                    006f100000d1fk1
# 1  Rwanda  ...                    006f100000d1fjw
# 2  Rwanda  ...                    006f100000a86I3
# 3  Rwanda  ...                    006f100000cPpL8
# 4  Rwanda  ...                    006f100000eescb
#
# [5 rows x 28 columns]

# %%
df_ordered.loc[df_ordered['Sector'] =='Masaka']
# Out:
#    Country Province  ...     CaseSafeID Form Bridge Opportunity: Opportunity ID
# 89  Rwanda   Kigali  ...  a1if1000002hT9zAAE                    006f100000a86Cs
#
# [1 rows x 28 columns]

# %%
output = df_ordered.to_json(orient="records")
parsed = json.loads(output)

# %%
json.dumps(parsed[0], sort_keys=False)
# Out:
# '{"Country": "Rwanda", "Province": "Western Province", "District": "Rusizi", "Dist_ID": "36", "Sector": "Giheke", "Sector_ID": "3605", "Cell": "Gakomeye", "Cell_ID": "360502", "Village": "Buzi", "Village_ID": "36050201", "Bridge Site Name": "Buzi", "Project Code": "1014107", "Bridge Type": "Suspended", "Project Stage": "Rejected", "Project Sub-Stage": "Technical", "Individuals Directly Served": 0, "Span (m)": 0, "GPS (Latitude)": -2.42056, "GPS (Longitude)": 28.9662, "Community Served 1": "Buzi", "Community Served 2": "Kabuga", "Community Served 3": "Kagarama", "Community Served 4": "Gacyamo", "Community Served 5": "Gasheke", "Communities_Served": ["Buzi", "Kabuga", "Kagarama", "Gacyamo", "Gasheke"], "Form: Form Name": "Project Assessment - 2018.10.29", "CaseSafeID Form": "a1if1000002e51bAAA", "Bridge Opportunity: Opportunity ID": "006f100000d1fk1"}'

# %%
parsed[0]
# Out:
# {'Bridge Opportunity: Opportunity ID': '006f100000d1fk1',
#  'Bridge Site Name': 'Buzi',
#  'Bridge Type': 'Suspended',
#  'CaseSafeID Form': 'a1if1000002e51bAAA',
#  'Cell': 'Gakomeye',
#  'Cell_ID': '360502',
#  'Communities_Served': ['Buzi', 'Kabuga', 'Kagarama', 'Gacyamo', 'Gasheke'],
#  'Community Served 1': 'Buzi',
#  'Community Served 2': 'Kabuga',
#  'Community Served 3': 'Kagarama',
#  'Community Served 4': 'Gacyamo',
#  'Community Served 5': 'Gasheke',
#  'Country': 'Rwanda',
#  'Dist_ID': '36',
#  'District': 'Rusizi',
#  'Form: Form Name': 'Project Assessment - 2018.10.29',
#  'GPS (Latitude)': -2.42056,
#  'GPS (Longitude)': 28.9662,
#  'Individuals Directly Served': 0,
#  'Project Code': '1014107',
#  'Project Stage': 'Rejected',
#  'Project Sub-Stage': 'Technical',
#  'Province': 'Western Province',
#  'Sector': 'Giheke',
#  'Sector_ID': '3605',
#  'Span (m)': 0,
#  'Village': 'Buzi',
#  'Village_ID': '36050201'}

# %%
## Data Output in .csv

# Getting current date to keep track of dataset changes
date = date.today()
print("Today's date:", date)

# site_assessment
filename_df_ordered = f'B2P_Rwanda_Sites+IDs_full_{date}.csv'



# Dataframe to .csv conversion
df_ordered.to_csv(filename_df_ordered)


# Placeholder for merged dataset
#merged.to_csv('merged.csv')
# Out:
# Today's date: 2020-09-16
