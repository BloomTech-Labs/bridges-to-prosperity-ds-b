# %%
# Imports
import numpy as np
import pandas as pd
from datetime import date

# %%
# # Load data
# df = pd.read_csv('https://raw.githubusercontent.com/Lambda-School-Labs/Labs25-Bridges_to_Prosperity-TeamB-ds/jakekrafczyk-patch-1/data/edit/B2P_Rwanda_MatchedIds.csv')
# df.drop('Unnamed: 0', 1, inplace=True)
df = pd.read_csv('https://raw.githubusercontent.com/Lambda-School-Labs/Labs25-Bridges_to_Prosperity-TeamB-ds/main/data/edit/B2P_Rwanda_Site_Assessment_Data_clean_2020-08-25.csv')
 
# df = pd.read_csv('https://github.com/Lambda-School-Labs/Labs25-Bridges_to_Prosperity-TeamB-ds/blob/main/data/edit/B2P_Rwanda_Site_Assessment_Data_clean_2020-08-25.csv')
# df.drop('Unnamed: 0', 1, inplace=True)
df.head()
# Out:
#    Unnamed: 0  ...                                   Community_served
# 0           0  ...           Buzi  Kabuga  Kagarama  Gacyamo  Gasheke
# 1           1  ...  Kabuga  Buzi  Gacyamo - Gasheke  Kagarama  Kanoga
# 2           2  ...  Gapfundo  Rusabira ( Gicumbi)  Merezo  Minanir...
# 3           3  ...
# 4           4  ...                            Gisizi  Nyabitare
#
# [5 rows x 25 columns]

# %%
df=df.drop(['Community_served'], axis=1)

# %%
import numpy as np
df['Community Served 1'] = df['Community Served 1'].fillna('?')
df['Community Served 2'] = df['Community Served 2'].fillna('?')
df['Community Served 3'] = df['Community Served 3'].fillna('?')
df['Community Served 4'] = df['Community Served 4'].fillna('?')
df['Community Served 5'] = df['Community Served 5'].fillna('?')

# %%
df['Community Served 1'].head(30)
# Out:
# 0                         Buzi
# 1                       Kabuga
# 2                     Gapfundo
# 3                            ?
# 4                       Gisizi
# 5                       Ruheka
# 6                         Raro
# 7     Kinkeri( karama sector )
# 8                     Nyenyeri
# 9                       Karama
# 10                    Bunyonga
# 11                    Bunyonga
# 12               Bugarama cell
# 13                  Rugobagoba
# 14                    Kagarama
# 15                 Kabuga cell
# 16                      Rubare
# 17       Entire cell of Murehe
# 18                      Rutare
# 19                      Kibobo
# 20                       Nkusi
# 21                Akarukambira
# 22                      Butezi
# 23                      Rebero
# 24                  Rugobagoba
# 25                Nyagatugunda
# 26                    Kabonero
# 27             Nyarukombe cell
# 28                   Bushobora
# 29                   Nyakajuri
# ...

# %%
# reordering df
column_order = ['Country', 'Province', 'District', 'Dist_ID', 'Sector', 'Sector_ID', 
                'Cell', 'Cell_ID', 'Village', 'Village_ID', 'Bridge Site Name', 
                'Project Code', 'Bridge Type', 'Project Stage', 'Project Sub-Stage', 
                'Individuals Directly Served', 'Span (m)', 'GPS (Latitude)', 
                'GPS (Longitude)', 'Community Served 1', 'Community Served 2', 
                'Community Served 3', 'Community Served 4', 'Community Served 5', 
                'Form: Form Name', 'CaseSafeID Form', 
                'Bridge Opportunity: Opportunity ID']
df = df.reindex(columns=column_order)
df.head(10)
# Out:
#   Country  ... Bridge Opportunity: Opportunity ID
# 0  Rwanda  ...                    006f100000d1fk1
# 1  Rwanda  ...                    006f100000d1fjw
# 2  Rwanda  ...                    006f100000a86I3
# 3  Rwanda  ...                    006f100000cPpL8
# 4  Rwanda  ...                    006f100000eescb
# 5  Rwanda  ...                    006f100000eescl
# 6  Rwanda  ...                    006f100000eesdZ
# 7  Rwanda  ...                    006f100000eesdK
# 8  Rwanda  ...                    006f100000eescv
# 9  Rwanda  ...                    006f100000eesdP
#
# [10 rows x 27 columns]

# %%
# # Renaming Column
# df_ordered = df_ordered.rename(columns = {'Community_served' : 'Communities_Served'})
# # 
# df_ordered['Communities_Served']

# %%
df.dtypes
# Out:
# Country                                object
# Province                               object
# District                               object
# Dist_ID                               float64
# Sector                                 object
# Sector_ID                             float64
# Cell                                   object
# Cell_ID                               float64
# Village                                object
# Village_ID                            float64
# Bridge Site Name                       object
# Project Code                           object
# Bridge Type                            object
# Project Stage                          object
# Project Sub-Stage                      object
# Individuals Directly Served           float64
# Span (m)                              float64
# GPS (Latitude)                        float64
# GPS (Longitude)                       float64
# Community Served 1                     object
# ...

# %%
# Converting from float to str
df['Community Served 1']=df['Community Served 1'].astype(str)
df['Community Served 2']=df['Community Served 2'].astype(str)
df['Community Served 3']=df['Community Served 3'].astype(str)
df['Community Served 4']=df['Community Served 4'].astype(str)
df['Community Served 5']=df['Community Served 5'].astype(str)

# %%
# count_sector=[]
# for i in df.index:

#   if 'sector' in df['communities_served'][i]:
#     count_sector.append(i)
#     # df['Community Served 1'].replace(df['Community Served 1'][i], '??', inplace = True)
    
    
# print(len(count_sector))

# %%
# check how many sector name in 5 collumns of Community Serverd. From following result , totally 25.
count_sector1=[]
for i in df.index:
  if ' sector' in df['Community Served 1'][i]:
    count_sector1.append(i)
    print(df['Community Served 1'][i])   
print("There are "+ str(len(count_sector1))+ " sector names in Community Served 1" + "\n" )


count_sector2=[]
for i in df.index:
  if ' sector' in df['Community Served 2'][i]:
    count_sector2.append(i)
    print(df['Community Served 2'][i]) 
print("There are "+ str(len(count_sector2))+ " sector names in Community Served 2" + "\n" )
 

count_sector3=[]
for i in df.index:

  if ' sector' in df['Community Served 3'][i]:
    count_sector3.append(i)
    print(df['Community Served 3'][i])     
print("There are "+ str(len(count_sector3))+ " sector names in Community Served 3" + "\n" )
 

count_sector4=[]
for i in df.index:
  if ' sector' in df['Community Served 4'][i]:
    count_sector4.append(i)
    print(df['Community Served 4'][i])    
print("There are "+ str(len(count_sector4))+ " sector names in Community Served 4"+ "\n" )
 


count_sector5=[]
for i in df.index:
  if ' sector' in df['Community Served 5'][i]:
    count_sector5.append(i)
    print(df['Community Served 5'][i])  
print("There are "+ str(len(count_sector5))+ " sector names in Community Served 5 "+ "\n" )
# Out:
# Kinkeri( karama sector )
# Kayenzi sector
# Nyamiyaga sector
# There are 3 sector names in Community Served 1
#
# Kamuhoza( Runda sector)
# Musambira sector
# Kayumbo sector
# Mubuga sector
# Entire karama sector
# Nyamiyaga sector
# There are 6 sector names in Community Served 2
#
# Gishyita sector
# Mugano sector
# Mugano sector
# Nyabikenke sector and ntwali
# Runda sector and Rugalika sector
# There are 5 sector names in Community Served 3
#
# Rangiro sector
# Entire kirimbi sector
# kirimbi sector
# Nyakabuye sector
# Bweyeye sector
# Twumba sector
# There are 6 sector names in Community Served 4
#
# Gahira cell, karama sector and kayenzi
# Entire shangi sector
# Karengera sector
# Mugano sector
# Mugano sector
# There are 5 sector names in Community Served 5

# %%
#Remove sector names in 5 Communty Served columns.
for i in df.index:
  if ' sector' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if ' sector' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if ' sector' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if ' sector' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if ' sector' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
#Remove sector names with "Sector" in 5 Communty Served columns.
for i in df.index:
  if ' Sector' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if ' Sector' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if ' Sector' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if ' Sector' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if ' Sector' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
 # check how many cell name in 5 Community Serverd. From following result , totally 146.
count_cell1=[]
for i in df.index:

  if ' cell' in df['Community Served 1'][i]:
    count_cell1.append(i)
    print(df['Community Served 1'][i])  
print("There are "+ str(len(count_cell1))+ " cell names in Community Served 1 "+ "\n" ) 


count_cell2=[]
for i in df.index:

  if ' cell' in df['Community Served 2'][i]:
    count_cell2.append(i)
    print(df['Community Served 2'][i])  
print("There are "+ str(len(count_cell2))+ " cell names in Community Served 2 "+ "\n" ) 


count_cell3=[]
for i in df.index:

  if ' cell' in df['Community Served 3'][i]:
    count_cell3.append(i)
    print(df['Community Served 3'][i])  
print("There are "+ str(len(count_cell3))+ " cell names in Community Served 3 "+ "\n" ) 


count_cell4=[]
for i in df.index:
  if ' cell' in df['Community Served 4'][i]:
    count_cell4.append(i)
    print(df['Community Served 4'][i])  
print("There are "+ str(len(count_cell4))+ " cell names in Community Served 4 "+ "\n" ) 



count_cell5=[]
for i in df.index:
  if ' cell' in df['Community Served 5'][i]:
    count_cell5.append(i)
    print(df['Community Served 5'][i])  
print("There are "+ str(len(count_cell5))+ " cell names in Community Served 5 "+ "\n" )
# Out:
# Bugarama cell
# Kabuga cell
# Entire cell of Murehe
# Nyarukombe cell
# Pera cell
# Gihinga cell
# Gikundamvura cell
# Sanza cell
# Buliba cell
# Kinunga cell
# Nyamagana cell
# Kibatsi cell
# Ndekwe cell
# Nyinya cell
# Kibatsi cell
# Rujambara cell
# Rwikubo cell
# Shyembe cell
# Rwikubo cell
# Akagarama cell
# Ndekwe cell
# Ruhinga cell
# Rugese cell
# Nyaruvumu cell
# Rubazo cell
# Nyagatugunda cell
# Kibatsi cell
# Gatonde cell
# Rujambara cell
# Remera cell
# Munege cell
# Umukamba cell
# Akaziba cell
# Munege cell
# Munege cell
# Nteko cell
# Karambo cell( Nyirakiraro and Nyamirama villages)
# Rwintashya cell
# Kinyana cell
# Gituza cell
# Ntaga cell
# Bwana cell
# Gituza cell
# Rubona cell
# The whole nyagatare cell
# Masangano cell
# Nkoma cell
# Gatonde cell
# Nyagasozi cell
# Nkanga cell
# Kindama cell
# Kabingo cell
# Byogo cell
# Entire mwezi cell
# Entire mataba cell
# Kabingo cell
# Kabingo cell
# Kindama cell
# Cubi cell
# Karambi cell
# Nawe cell
# Mbati cell
# ...

# %%
#Remove cell names in 5 Communty Served columns.
for i in df.index:
  if ' cell' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if ' cell' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if ' cell' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if ' cell' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if ' cell' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
df.head()
# Out:
#   Country  ... Bridge Opportunity: Opportunity ID
# 0  Rwanda  ...                    006f100000d1fk1
# 1  Rwanda  ...                    006f100000d1fjw
# 2  Rwanda  ...                    006f100000a86I3
# 3  Rwanda  ...                    006f100000cPpL8
# 4  Rwanda  ...                    006f100000eescb
#
# [5 rows x 27 columns]

# %%
# Remove "village"  in 5 Community served collumns.

df['Community Served 1'] = df['Community Served 1'].str.replace('village',"?")
df['Community Served 2'] = df['Community Served 2'].str.replace('village',"?")
df['Community Served 3'] = df['Community Served 3'].str.replace('village',"?")
df['Community Served 4'] = df['Community Served 4'].str.replace('village',"?")
df['Community Served 5'] = df['Community Served 5'].str.replace('village',"?")

# %%
# # Remove '-' in 5 Community served columns. 
# df['Community Served 1'] = df['Community Served 1'].str.replace('-',', ')
# df['Community Served 2'] = df['Community Served 2'].str.replace('-',', ')
# df['Community Served 3'] = df['Community Served 3'].str.replace('-',', ')
# df['Community Served 4'] = df['Community Served 4'].str.replace('-',', ')
# df['Community Served 5'] = df['Community Served 5'].str.replace('-',', ')

# %%
# Remove values with '-' in 5 Community served columns. 
for i in df.index:
  if '-' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if '-' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if '-' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if '-' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if '-' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
# Remove values with '_' in 5 Community served columns. 
for i in df.index:
  if '_' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if '_' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if '_' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if '_' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if '_' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
# There are 26 with ( ) in 5 Community Served Columns
print('With ( ) in Community Served 1:')
for i in df.index:    
  if '(' in df['Community Served 1'][i]:
    print(df['Community Served 1'][i])

print("\n"+ 'With ( ) in Community Served 2:')
for i in df.index:
  if '(' in df['Community Served 2'][i]:
    print(df['Community Served 2'][i])

print("\n"+ 'With ( ) in Community Served 3:')
for i in df.index:
  if '(' in df['Community Served 3'][i]:
    print(df['Community Served 3'][i])


print("\n"+ 'With ( ) in Community Served 4:')
for i in df.index:
  if '(' in df['Community Served 4'][i]:
    print(df['Community Served 4'][i])

print("\n"+ 'With ( ) in Community Served 5:')
for i in df.index:
  if '(' in df['Community Served 5'][i]:
    print(df['Community Served 5'][i])
# Out:
# With ( ) in Community Served 1:
# Kagarama (Nyacyonga
# Rwambeho (Butare)
# Mpazi (Kabeza)
# Rususa (Nyakariro)
#
# With ( ) in Community Served 2:
# Rusabira ( Gicumbi)
# Ryabishanga (Butare)
# Gasharu(rutare)
# (Umukoke) Karambo
# Masaka (Rugarika)
# Kigarama(Rususa)
# Mubirembo (Gatsibo)
# Kigarama(Bwama)
# Kibungo (Kagoma)
# Rugarika (Kamonyi)
# Mpazi(katabaro)
#
# With ( ) in Community Served 3:
# Kabingo (Butete)
# Nyarusange (Rwamagana)
# Rususa (Masaka)
# Ruvomo (Nzige)
#
# With ( ) in Community Served 4:
# Kigarama (on the RHS )
# Gatare (Gatovu Cell )
# Gikunze (Nyaruguru District)
# Ruramira (without Agasharu and Buhoro)
# Ruvomo (Muyumbu)
#
# With ( ) in Community Served 5:
# Gatare (Kansi)
# Gatare (Akabogoti Cell)
# Kigarama (on the RHS )

# %%
# Remove values with '( )' in 5 Community served columns. 
for i in df.index:
  if '(' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if '(' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if '(' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if '(' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if '(' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
# # Remove "_"  in 5 Community served collumns.

# df['Community Served 1'] = df['Community Served 1'].str.replace('_',"?")
# df['Community Served 2'] = df['Community Served 2'].str.replace('_',"?")
# df['Community Served 3'] = df['Community Served 3'].str.replace('_',"?")
# df['Community Served 4'] = df['Community Served 4'].str.replace('_',"?")
# df['Community Served 5'] = df['Community Served 5'].str.replace('_',"?")

# %%
# Remove "1"  in 5 Community served collumns.

df['Community Served 1'] = df['Community Served 1'].str.replace('1',"")
df['Community Served 2'] = df['Community Served 2'].str.replace('1',"")
df['Community Served 3'] = df['Community Served 3'].str.replace('1',"")
df['Community Served 4'] = df['Community Served 4'].str.replace('1',"")
df['Community Served 5'] = df['Community Served 5'].str.replace('1',"")

# %%
# Remove "2"  in 5 Community served collumns.

df['Community Served 1'] = df['Community Served 1'].str.replace('2',"")
df['Community Served 2'] = df['Community Served 2'].str.replace('2',"")
df['Community Served 3'] = df['Community Served 3'].str.replace('2',"")
df['Community Served 4'] = df['Community Served 4'].str.replace('2',"")
df['Community Served 5'] = df['Community Served 5'].str.replace('2',"")

# %%
# # Remove " A"  in 5 Community served collumns.

# df['Community Served 1'] = df['Community Served 1'].str.replace('A',"")
# df['Community Served 2'] = df['Community Served 2'].str.replace('A',"")
# df['Community Served 3'] = df['Community Served 3'].str.replace('A',"")
# df['Community Served 4'] = df['Community Served 4'].str.replace('A','')
# df['Community Served 5'] = df['Community Served 5'].str.replace('A','')

# %%
# # Remove " B"  in 5 Community served collumns.

# df['Community Served 1'] = df['Community Served 1'].str.replace('B','')
# df['Community Served 2'] = df['Community Served 2'].str.replace('B','')
# df['Community Served 3'] = df['Community Served 3'].str.replace('B','')
# df['Community Served 4'] = df['Community Served 4'].str.replace('B','')
# df['Community Served 5'] = df['Community Served 5'].str.replace('B','')

# %%
# Remove values with ' center' in 5 Community served columns. 
for i in df.index:
  if ' center' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if ' center' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if ' center' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if ' center' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if ' center' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
# Remove values with ' Center' in 5 Community served columns. 
for i in df.index:
  if ' Center' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if ' Center' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if ' Center' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if ' Center' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if ' Center' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
# Remove values with '&' in 5 Community served columns. 
for i in df.index:
  if '&' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if '&' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if '&' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if '&' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if '&' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
# Remove values with ' and ' in 5 Community served columns. 
for i in df.index:
  if ' and ' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if ' and ' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if ' and ' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if ' and 'in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if ' and ' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
 # Remove values with ',' in 5 Community served columns. 
for i in df.index:
  if ',' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if ',' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if ',' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if ',' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if ',' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
 # Remove values with ' of ' in 5 Community served columns. 
for i in df.index:
  if ' of ' in df['Community Served 1'][i]:
    df['Community Served 1'].replace(df['Community Served 1'][i], "?", inplace = True)

  if ' of ' in df['Community Served 2'][i]:
    df['Community Served 2'].replace(df['Community Served 2'][i], "?", inplace = True)

  if ' of ' in df['Community Served 3'][i]:
    df['Community Served 3'].replace(df['Community Served 3'][i], "?", inplace = True)

  if ' of ' in df['Community Served 4'][i]:
    df['Community Served 4'].replace(df['Community Served 4'][i], "?", inplace = True)


  if ' of ' in df['Community Served 5'][i]:
    df['Community Served 5'].replace(df['Community Served 5'][i], "?", inplace = True)

# %%
# sites_ids_subset['communities_served'] = (sites_ids_subset['community_served_1'] 
# +", "+ sites_ids_subset['community_served_2']+", "+ sites_ids_subset['community_served_3']
# +", "+ sites_ids_subset['community_served_4']+", "+ sites_ids_subset['community_served_5'])

# %%
df['Communities_Served_Sum'] = (df['Community Served 1'] 
+", "+ df['Community Served 2']+", "+ df['Community Served 3']
+", "+ df['Community Served 4']+", "+ df['Community Served 5'])
df['Communities_Served_Sum'].head(20)
# Out:
# 0         Buzi, Kabuga, Kagarama, Gacyamo, Gasheke
# 1                Kabuga, Buzi, ?, Kagarama, Kanoga
# 2         Gapfundo, ?, Merezo, Minanire, Karutongo
# 3                                    ?, ?, ?, ?, ?
# 4                       Gisizi, Nyabitare, ?, ?, ?
# 5                          Ruheka, Kabana, ?, ?, ?
# 6                                 Raro, ?, ?, ?, ?
# 7                                    ?, ?, ?, ?, ?
# 8                 Nyenyeri, Bunyonga, Kavumu, ?, ?
# 9      Karama, Kagarama, Ryabitana, Nyarunyinya, ?
# 10                            Bunyonga, ?, ?, ?, ?
# 11                Bunyonga, Nyarurembo, Gaji, ?, ?
# 12                                   ?, ?, ?, ?, ?
# 13                     Rugobagoba, Rubona, ?, ?, ?
# 14    Kagarama, Ryabitana, Karama, Rugogwe, Karehe
# 15                                   ?, ?, ?, ?, ?
# 16                              Rubare, ?, ?, ?, ?
# 17                     ?, Kabagesera, Gihara, ?, ?
# ...

# %%
 type(df['Communities_Served_Sum'])
# Out:
# pandas.core.series.Series

# %%
df['Communities_Served_Sum'].head(20)
# Out:
# 0         Buzi, Kabuga, Kagarama, Gacyamo, Gasheke
# 1                Kabuga, Buzi, ?, Kagarama, Kanoga
# 2         Gapfundo, ?, Merezo, Minanire, Karutongo
# 3                                    ?, ?, ?, ?, ?
# 4                       Gisizi, Nyabitare, ?, ?, ?
# 5                          Ruheka, Kabana, ?, ?, ?
# 6                                 Raro, ?, ?, ?, ?
# 7                                    ?, ?, ?, ?, ?
# 8                 Nyenyeri, Bunyonga, Kavumu, ?, ?
# 9      Karama, Kagarama, Ryabitana, Nyarunyinya, ?
# 10                            Bunyonga, ?, ?, ?, ?
# 11                Bunyonga, Nyarurembo, Gaji, ?, ?
# 12                                   ?, ?, ?, ?, ?
# 13                     Rugobagoba, Rubona, ?, ?, ?
# 14    Kagarama, Ryabitana, Karama, Rugogwe, Karehe
# 15                                   ?, ?, ?, ?, ?
# 16                              Rubare, ?, ?, ?, ?
# 17                     ?, Kabagesera, Gihara, ?, ?
# ...

# %%
#load official village data
names_codes = pd.read_csv('https://raw.githubusercontent.com/Lambda-School-Labs/Labs25-Bridges_to_Prosperity-TeamB-ds/main/data/raw/Rwanda_Administrative_Levels_and_Codes_Province_through_Village.csv')
names_codes.head()
# Out:
#    Prov_ID   Province  Dist_ID  District  ...   Vill_ID    Village  Status   FID
# 0        2  Amajyepfo       22  Gisagara  ...  22050101    Agahehe   Rural  1842
# 1        2  Amajyepfo       22  Gisagara  ...  22050102   Kabacuzi   Rural  1846
# 2        2  Amajyepfo       22  Gisagara  ...  22050103   Kamutozo   Rural  1854
# 3        2  Amajyepfo       22  Gisagara  ...  22050104    Kamweko   Rural  1866
# 4        2  Amajyepfo       22  Gisagara  ...  22050105  Nyamabuye   Rural  1873
#
# [5 rows x 12 columns]

# %%
gov_village = names_codes.Village.unique()
btp_community1 = df['Community Served 1'].unique()
btp_community2 = df['Community Served 2'].unique()

btp_community1
# Out:
# array(['Buzi', 'Kabuga', 'Gapfundo', '?', 'Gisizi', 'Ruheka', 'Raro',
#        'Nyenyeri', 'Karama', 'Bunyonga', 'Rugobagoba', 'Kagarama',
#        'Rubare', 'Rutare', 'Kibobo', 'Nkusi', 'Akarukambira', 'Butezi',
#        'Rebero', 'Nyagatugunda', 'Kabonero', 'Bushobora', 'Nyakajuri',
#        'Kiruhura', 'Rugarama', 'Rutunga', 'Nyaburanga', 'Kinunga',
#        'Rwayikona', 'Akamabuye', 'Cyeru', 'Nyarubuye', 'Kabare',
#        'Barisuka', 'Murama', 'Gatari', 'Nyagasenyi', 'Bugarura',
#        'Kabigembe ', 'Mitsindo', 'Rurenge', 'Bingaro', 'Bwiyorere',
#        'Munini', 'Saruhembe', 'Ruramira', 'Nyamiyaga', 'Kabarore',
#        'Karambo', 'Rwarugaju', 'Rurama', 'Nombe', 'Gacyamo', 'Gasumo',
#        'Kiziguro', 'Kanoga', 'Kigarama', 'Rukurazo', 'Kagogo', 'Rusave',
#        'Kintenko', 'Ruhamagariro', 'Gatoki', 'Murambi', 'Runyinya',
#        'Ruhuha', 'Nyagasayo', 'Buyoga', 'Sokofi', 'Juru', 'Gahosha',
#        'Cyasemakamba', 'Yaramba', 'Rushwati', 'Ndengerezi', 'Munkamba',
# ...

# %%
# check to make sure they all match
y1 = []
for x1 in btp_community1:
  if x1 not in gov_village:
    y1.append(x1)
    print(x1)

print(len(y1))
# Out:
# Gapfundo
# ?
# Nkusi
# Akarukambira
# Bushobora
# Kabigembe
# Bwiyorere
# Ruramira
# Kintenko
# Musya Cell
# Cyingwa
# Gahurire
# Bayigurire
# Materaza
# Birenga
# Karama centre
# Kimbazi
# Nyabizi
# Mbarara
# Nyakizi
# Bishgiga
# Rusekera ?
# Ndongoshoru
# Buheta
# Musangamo
# Gasugi
# Buliba
# Gahima
# Rubazo
# Mahango
# Kabogoti
# Kavumu
# Nyabushingitwa
# Nyarwina ?
# Rwarurema ?
# Rwaninka
# Ruhembe
# Kabatasi
# Bwana
# Gati
# Rubaya centre
# Gahana
# Kamashima
# Cercle sportif
# Mwunyu
# Kiciro
# Mugwato ?
# Murengere
# MONT cyangugu
# Rushungura
# Kanyobya
# Rwangenge
# Nyakibirira
# M
# Rugesha
# Mugobate
# Rubenga
# Karabata
# Gitinsi
# Gahuriro
# Mutenderi
# Nyiragokokora
# Kamurabi
# Rwinkanka
# Ggg
# Butanda
# Bweyeye
# Bombaniro
# Murengezo
# Peru ?
# Nkegete ?
# Rubuye ?
# Ndayabane Nyabushingitwa
# Mutuntu ?
# Mwimereri
# GASHUBI
# Byimana ?
# Nyantwa ?
# Rugogo ?
# Antenne
# Niboye
# Abarezi
# Nyarushekera ?
# Kamukunzi
# Kinyambogo
# Ginango
# Muvembwe
# Karama ?
# ...

# %%
 # check to make sure community served 2 matched with village id
y2 = []
for x2 in btp_community2:
  if x2 not in gov_village:
    y2.append(x2)
    print(x2)

print(len(y2))
# Out:
# ?
# Nyabayamo
# Munyaga
# GaharaI
# Mukori
# Mahango
# Kibangu
# Gahungere
# Rwesheke
# Karushu
# Cyenjojo
# Gahurire
# Musya
# Bimuli
# Karega
# Ngayaki
# Gashyamba
# Rwungu
# Nyirarunazi
# Nyabizi
# Rucura
# Nyabizi 3
# Kiligali
# Ngarurira
# Rwanyirangeri
# Bwerere
# Nzaratsa
# Gasata
# Kavumu
# Karwishyura
# Mukono
# Bwuhira ?
# Sunzu ?
# Ntwali
# Uwingogo
# Birenga
# Cyamigurwa
# Mariza
# Kimbazi
# Cyarukamba
# Bukuyo
# Mbwe
# Cyimigo
# Nyagasozi ?
# Rugogwe ?
# Ruskoka
# Bisanganiro
# Kabacuku
# Mugereki
# Ntantabo
# Ngambe
# Keshero
# Gigeta
# Munega
# Nyabishongore
# Kibagabaga
# Nyabikenye
# Gahororo/Gitabura
# Burundiro
# Gatereri
# Nzahaha
# Buyoga ?
# Mucyahafi
# Peru ?
# Rasaniro ?
# Gahuni
# Murengezo
# Himbo ?
# Marero
# Muvumba ?
# Nyiramiryango
# Abarezi
# Kidashya
# Mahembe ?
# Ryampande ?
# Cyirimbi
# Gihande
# Nyanjondori
# Nyagagasozi
# Muyange ?
# Subukiniro ?
# Bushigishigi ?
# Gisoro ?
# Karuyumbu
# Rutagara
# Kamatare ?
# Mwumba ?
# Rwamambe/bushoka
# ...

# %%
# create a subset with village and Id from   government village data
Village_key = names_codes[['Village','Vill_ID']].drop_duplicates('Vill_ID')
Village_key.shape
# Out:
# (14816, 2)

# %%
# def match_comm_id(comm_name):
#   for i in df.index:
#     community1 = df['Community Served 1'][i]
#     if community1 in Village_key['Village']:
#       for j in Village_key.index:
#         while df['community1'][i]==Village_key['Village'][j]:
#           return new_list ==Village_key['Vill_ID'][j]
#     if community1 not in Village_key['Village']:
#           return new_list==None

# %%
# new_list=[]

# for comm_name in df['Community Served 1']:
#   new_list.append(match_comm_id(comm_name))



# df['Community1_ID']=pd.Series(new_list)
# df['Community1_ID'].head()

# %%
# Data Output in .csv.   Aim for deep cleaning Community Served

# Getting current date to keep track of dataset changes
date = date.today()
print("Today's date:", date)

# site_assessment
filename_df_ordered = f'B2P_Rwanda_site_assesment{date}.csv'

# Dataframe to .csv conversion
df.to_csv(filename_df_ordered)
# Out:
# Today's date: 2020-09-23

# %%
df.head()
# Out:
#   Country  ...                    Communities_Served_Sum
# 0  Rwanda  ...  Buzi, Kabuga, Kagarama, Gacyamo, Gasheke
# 1  Rwanda  ...         Kabuga, Buzi, ?, Kagarama, Kanoga
# 2  Rwanda  ...  Gapfundo, ?, Merezo, Minanire, Karutongo
# 3  Rwanda  ...                             ?, ?, ?, ?, ?
# 4  Rwanda  ...                Gisizi, Nyabitare, ?, ?, ?
#
# [5 rows x 28 columns]
