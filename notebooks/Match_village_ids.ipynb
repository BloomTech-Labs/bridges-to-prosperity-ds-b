# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/Lambda-School-Labs/Labs25-Bridges_to_Prosperity-TeamB-ds/feature/df_to_csv_jake/data/edit/B2P_Rwanda_Site_Assessment_Data_clean_2020-08-25.csv',index_col=0,)
df.head()
# Out:
#   Country  ...                                   Community_served
# 0  Rwanda  ...           Buzi  Kabuga  Kagarama  Gacyamo  Gasheke
# 1  Rwanda  ...  Kabuga  Buzi  Gacyamo - Gasheke  Kagarama  Kanoga
# 2  Rwanda  ...  Gapfundo  Rusabira ( Gicumbi)  Merezo  Minanir...
# 3  Rwanda  ...
# 4  Rwanda  ...                            Gisizi  Nyabitare
#
# [5 rows x 24 columns]

# %%
df.fillna('', inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                               0
# Province                              0
# District                              0
# Sector                                0
# Cell                                  0
# Bridge Site Name                      0
# Project Stage                         0
# Project Sub-Stage                     0
# Project Code                          0
# Bridge Type                           0
# Span (m)                              0
# GPS (Latitude)                        0
# GPS (Longitude)                       0
# Individuals Directly Served           0
# Form: Form Name                       0
# Community Served 1                    0
# Community Served 2                    0
# Community Served 3                    0
# Community Served 4                    0
# Community Served 5                    0
# CaseSafeID Form                       0
# Bridge Opportunity: Opportunity ID    0
# Village                               0
# Community_served                      0
# dtype: int64

# %%
names_codes = pd.read_csv('https://raw.githubusercontent.com/Lambda-School-Labs/Labs25-Bridges_to_Prosperity-TeamB-ds/main/data/raw/Rwanda_Administrative_Levels_and_Codes_Province_through_Village.csv')
names_codes.head()
# Out:
#    Prov_ID   Province  Dist_ID  District  ...   Vill_ID    Village  Status   FID
# 0        2  Amajyepfo       22  Gisagara  ...  22050101    Agahehe   Rural  1842
# 1        2  Amajyepfo       22  Gisagara  ...  22050102   Kabacuzi   Rural  1846
# 2        2  Amajyepfo       22  Gisagara  ...  22050103   Kamutozo   Rural  1854
# 3        2  Amajyepfo       22  Gisagara  ...  22050104    Kamweko   Rural  1866
# 4        2  Amajyepfo       22  Gisagara  ...  22050105  Nyamabuye   Rural  1873
#
# [5 rows x 12 columns]

# %%
names_codes.shape
# Out:
# (14816, 12)

# %%
# Problem 1 - several totally different villages have the same names
names_codes.Village.value_counts()
# Out:
# Kabeza        148
# Rugarama      122
# Murambi       119
# Kigarama      113
# Rebero        103
#              ...
# Guriro          1
# Nyarukore       1
# Rusheshi        1
# Cyinganzwa      1
# Kabaguma        1
# Name: Village, Length: 6599, dtype: int64

# %%
# several cells also have the same names
names_codes[names_codes.Village == 'Kabeza'].Cell.value_counts()
# Out:
# Kabeza       5
# Mataba       2
# Munini       2
# Nyamiyaga    2
# Mwendo       2
#             ..
# Buliba       1
# Butezi       1
# Mberi        1
# Gishororo    1
# Ruhembe      1
# Name: Cell, Length: 133, dtype: int64

# %%
# here are 5 different villages in 5 different cells that all have same village name and cell name
names_codes[names_codes.Village == 'Kabeza'][names_codes.Cell == 'Kabeza']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       Prov_ID          Province  Dist_ID  ... Village  Status    FID
# 4239        5     Iburasirazuba       57  ...  Kabeza   Rural  14547
# 4270        1  Umujyi wa Kigali       13  ...  Kabeza   Urban   1001
# 4278        5     Iburasirazuba       52  ...  Kabeza   Rural  11264
# 4289        5     Iburasirazuba       52  ...  Kabeza   Rural  12385
# 4293        5     Iburasirazuba       53  ...  Kabeza   Rural  12397
#
# [5 rows x 12 columns]

# %%
names_codes.Sector.value_counts()
# Out:
# Ruhango       165
# Remera        131
# Muganza       113
# Kigoma        112
# Busasamana    107
#              ...
# Kagarama       15
# Kayumbu        15
# Rwezamenyo     15
# Gisozi         14
# Mageragere      1
# Name: Sector, Length: 388, dtype: int64

# %%
# there are also different sectors with the same name
names_codes[names_codes.Sector == 'Ruhango']["Sect_ID"].value_counts()
# Out:
# 2609    127
# 3212     38
# Name: Sect_ID, dtype: int64

# %%
names_codes[names_codes.Sector == 'Ruhango'][0:60]
# Out:
#       Prov_ID        Province  Dist_ID  ...      Village  Status   FID
# 731         2       Amajyepfo       26  ...       Buhoro   Rural  3900
# 732         2       Amajyepfo       26  ...         Gako   Rural  3907
# 733         2       Amajyepfo       26  ...       Kabeza   Rural  3916
# 734         2       Amajyepfo       26  ...      Kantama   Rural  3923
# 735         2       Amajyepfo       26  ...      Karambo   Rural  3930
# 736         2       Amajyepfo       26  ...   Muhororo I   Rural  3938
# 737         2       Amajyepfo       26  ...  Muhororo Ii   Rural  3944
# 738         2       Amajyepfo       26  ...   Ntinyinshi   Rural  3952
# 739         2       Amajyepfo       26  ...    Nyagasozi   Rural  3959
# 740         2       Amajyepfo       26  ...  Nyangandika   Rural  3965
# 741         2       Amajyepfo       26  ...    Nyarutovu   Rural  3971
# 742         2       Amajyepfo       26  ...     Rwinkuba   Rural  3978
# 890         2       Amajyepfo       26  ...     Bugarura   Rural  3651
# 891         2       Amajyepfo       26  ...       Busego   Rural  3658
# 892         2       Amajyepfo       26  ...       Gacoko   Rural  3666
# 893         2       Amajyepfo       26  ...   Gishegesha   Rural  3676
# 894         2       Amajyepfo       26  ...       Kabega   Rural  3683
# 895         2       Amajyepfo       26  ...     Kamugaru   Rural  3691
# 896         2       Amajyepfo       26  ...     Kamugaza   Rural  3699
# 897         2       Amajyepfo       26  ...       Karehe   Rural  3706
# 898         2       Amajyepfo       26  ...  Kasemahundo   Rural  3714
# 899         2       Amajyepfo       26  ...       Kavumu   Rural  3722
# 900         2       Amajyepfo       26  ...     Kigabiro   Rural  3730
# 901         2       Amajyepfo       26  ...     Kigarama   Rural  3738
# 902         2       Amajyepfo       26  ...       Murehe   Rural  3746
# 903         2       Amajyepfo       26  ...    Nyabibugu   Rural  3754
# 904         2       Amajyepfo       26  ...   Nyabisindu   Rural  3762
# 905         2       Amajyepfo       26  ...       Remera   Rural  3770
# 906         2       Amajyepfo       26  ...       Rubazi   Rural  3778
# 907         2       Amajyepfo       26  ...     Rusebeya   Rural  3787
# 908         2       Amajyepfo       26  ...     Rwankuba   Rural  3809
# 2928        3  Iburengerazuba       32  ...       Gasovu   Rural  5891
# 2929        3  Iburengerazuba       32  ...       Gasoyo   Rural  5898
# 2930        3  Iburengerazuba       32  ...   Kamuramira   Rural  5899
# 2931        3  Iburengerazuba       32  ...      Kirinja   Rural  5902
# 2932        3  Iburengerazuba       32  ...      Mwurire   Rural  5905
# 2933        3  Iburengerazuba       32  ...      Ruhimbi   Rural  5910
# 2934        3  Iburengerazuba       32  ...    Rukenesha   Rural  5912
# 3262        3  Iburengerazuba       32  ...      Bitenga   Rural  5915
# 3263        3  Iburengerazuba       32  ...      Busenda   Rural  5919
# 3264        3  Iburengerazuba       32  ...  Karambagiro   Rural  5921
# 3265        3  Iburengerazuba       32  ...  Kinyenkanda   Rural  5924
# 3266        3  Iburengerazuba       32  ...      Murambi   Rural  5927
# 3267        3  Iburengerazuba       32  ...       Rukoko   Rural  5931
# 3268        3  Iburengerazuba       32  ...         Tara   Rural  5934
# 3352        2       Amajyepfo       26  ...    Gatengeri   Rural  3816
# 3353        2       Amajyepfo       26  ...      Gikumba   Rural  3824
# 3354        2       Amajyepfo       26  ...       Karama   Rural  3832
# 3355        2       Amajyepfo       26  ...      Murambi   Rural  3840
# 3356        2       Amajyepfo       26  ...  Nangurugomo   Rural  3848
# 3357        2       Amajyepfo       26  ...   Nyarusange   Rural  3857
# 3358        2       Amajyepfo       26  ...       Rebero   Rural  3865
# 3359        2       Amajyepfo       26  ...       Rubiha   Rural  3872
# 3360        2       Amajyepfo       26  ...      Rurembo   Rural  3879
# 3361        2       Amajyepfo       26  ...  Ryabonyinka   Rural  3886
# 3362        2       Amajyepfo       26  ...       Wimana   Rural  3894
# 5831        3  Iburengerazuba       32  ...       Gakeri   Rural  5937
# 5832        3  Iburengerazuba       32  ...       Gasasa   Rural  5940
# 5833        3  Iburengerazuba       32  ...      Gasunzu   Rural  5943
# 5834        3  Iburengerazuba       32  ...     Mubirizi   Rural  5947
#
# [60 rows x 12 columns]

# %%
names_codes.District.value_counts()
# Out:
# Gicumbi       630
# Nyagatare     628
# Gakenke       617
# Kirehe        612
# Gatsibo       602
# Rusizi        596
# Nyamasheke    588
# Bugesera      581
# Burera        571
# Karongi       538
# Nyamagabe     536
# Ruhango       533
# Gisagara      524
# Rubavu        519
# Huye          508
# Rulindo       494
# Gasabo        486
# Rutsiro       484
# Rwamagana     474
# Nyabihu       473
# Ngoma         473
# Musanze       432
# Kayonza       421
# Nyanza        420
# Ngororero     419
# Nyarugenge    350
# Nyaruguru     332
# Muhanga       331
# Kicukiro      327
# Kamonyi       317
# Name: District, dtype: int64

# %%
# there are 30 districts(as there should be) and all only have one id, so we can start at Districts
print(len(names_codes.District.unique()))
len(names_codes.Dist_ID.unique())
# Out:
# 30
# 30

# %%
# now need to check the BTP dataset
len(df.District.unique())
# Out:
# 30

# %%
btp_dist = df.District.unique()
gov_dist = names_codes.District.unique()

# %%
# check to make sure they all match
y = []
for x in btp_dist:
  if x not in gov_dist:
    y.append(x)
    print(x)

print(len(y))
# Out:
# 0

# %%
# make sure all the gov entries are in a capitalized format
names_codes['Sector'] = names_codes.Sector.str.capitalize() 
names_codes['Cell'] = names_codes.Cell.str.capitalize() 
names_codes['Village'] = names_codes.Village.str.capitalize()

# %%
# they do- now check Sectors
btp_sect = df.Sector.unique()
gov_sect = names_codes.Sector.unique()

# %%
# check to see if they match. The btp dataset has entries with two sectors, eg 'Shyorongi-Jari'
# so lets look to see if gov districts are IN btp entries
y = []
for x in gov_sect:
  if x not in btp_sect:
    y.append(x)
    #print(x)

print(len(y))
y[0:9]

# There are 116 sector values in the gov dataset that are not in the btp dataset
# Out:
# 116
# ['Kiziguro',
#  'Jali',
#  'Kansi',
#  'Kiramuruzi',
#  'Rurenge',
#  'Nzige',
#  'Gisenyi',
#  'Muhima',
#  'Masaka']

# %%
names_codes.Sector.value_counts()
# Out:
# Ruhango       165
# Remera        131
# Muganza       113
# Kigoma        112
# Busasamana    107
#              ...
# Kagarama       15
# Kayumbu        15
# Rwezamenyo     15
# Gisozi         14
# Mageragere      1
# Name: Sector, Length: 380, dtype: int64

# %%
# now check if btp sectors are in the gov dataset, excluding values with two sectors
y = []
count = 0
for x in btp_sect:
  if "-" not in x:
    count += 1
    if x not in gov_sect:
      y.append(x)
      #print(x)

print('number of non hyphenated sectors in btp dataset',count)
print('number of unmatched sectors in btp dataset',len(y))
y

# There are 36 sector values in the btp dataset that are not in the gov dataset
# These are of more concern, as we cannot give them ids if they are not in the government dataset
# Out:
# number of non hyphenated sectors in btp dataset 300
# number of unmatched sectors in btp dataset 36
# ['Mushikir',
#  'Pera',
#  'Rusheshe',
#  'Kamanyenga',
#  'Kibingo',
#  'Katabagema',
#  'Kabukuba',
#  'Nyagihinga',
#  'Gishari',
#  'Gorwe',
#  'Mwili',
#  'Buruhukioro',
#  'Buheta',
#  'Rerenge',
#  'Terimbere',
#  'Bwisìge',
#  'Rulindo',
#  'Koza',
#  'Gushali',
#  'Ngarurira',
#  'Mulinga',
#  'Cyobe',
#  'Nkaka',
#  'Kabagari',
#  'Kamuragi',
#  'Giko',
#  'Gasakka',
#  'Gatsatagisozi',
#  'Cyingwa',
#  'Rugamba',
#  'Rugalika',
#  'Nyirangarama',
#  'Gikheke',
#  'Bushonyi',
#  'Mutongo',
#  'Nyakabingo']

# %%
# check if any of these values are cells

gov_cells = names_codes.Cell.unique()
sect_cell = []

for x in y:
  if x in gov_cells:
    sect_cell.append(x)

print('matching Cells',len(sect_cell),'\n',sect_cell)

# check if any of these values are Districts
sect_dist = []

for x in y:
  if x in gov_dist:
    sect_dist.append(x)

print('matching Districts',len(sect_dist),'\n',sect_dist)

# check if any of these values are villages
gov_vills = names_codes.Village.unique()
sect_vill = []

for x in y:
  if x in gov_vills:
    sect_vill.append(x)

print('matching Villages',len(sect_vill),'\n',sect_vill)
# Out:
# matching Cells 19
#  ['Pera', 'Rusheshe', 'Kamanyenga', 'Kibingo', 'Kabukuba', 'Gishari', 'Gorwe', 'Buheta', 'Terimbere', 'Rulindo', 'Ngarurira', 'Mulinga', 'Cyobe', 'Giko', 'Cyingwa', 'Rugamba', 'Nyirangarama', 'Mutongo', 'Nyakabingo']
# matching Districts 1
#  ['Rulindo']
# matching Villages 20
#  ['Pera', 'Rusheshe', 'Kamanyenga', 'Kibingo', 'Kabukuba', 'Nyagihinga', 'Gishari', 'Gorwe', 'Mwili', 'Terimbere', 'Rulindo', 'Cyobe', 'Kabagari', 'Kamuragi', 'Giko', 'Rugamba', 'Nyirangarama', 'Bushonyi', 'Mutongo', 'Nyakabingo']

# %%
# check how many of the cells and villages entries are the same
same = []
for x in sect_vill:
  if x in sect_cell:
    same.append(x)

print(len(same))
same
# Out:
# 15
# ['Pera',
#  'Rusheshe',
#  'Kamanyenga',
#  'Kibingo',
#  'Kabukuba',
#  'Gishari',
#  'Gorwe',
#  'Terimbere',
#  'Rulindo',
#  'Cyobe',
#  'Giko',
#  'Rugamba',
#  'Nyirangarama',
#  'Mutongo',
#  'Nyakabingo']

# %%
# so we have these 15 same(could be either cell/village) values + 4 unique cell values + 5 unique village values + 1 unique District value = 
# 25 out of the 36 missing sectors

# add/merge the district ids to the btp dataset
df.shape
# Out:
# (1423, 24)

# %%
# create an ID key for the district values
dist_key = names_codes[['District','Dist_ID']].drop_duplicates('Dist_ID')
dist_key.shape
# Out:
# (30, 2)

# %%
# create a new column in the btp dataset that includes district IDs
df['Dist_ID'] = df['District'].map(dist_key.set_index('District')['Dist_ID'])
df.head()
# Out:
#   Country  ... Dist_ID
# 0  Rwanda  ...      36
# 1  Rwanda  ...      36
# 2  Rwanda  ...      41
# 3  Rwanda  ...      45
# 4  Rwanda  ...      28
#
# [5 rows x 25 columns]

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading https://files.pythonhosted.org/packages/43/ff/74f23998ad2f93b945c0309f825be92e04e0348e062026998b5eefef4c33/fuzzywuzzy-0.18.0-py2.py3-none-any.whl
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
# find a "similar spelling identifier" function
# fuzzywuzzy - https://www.datacamp.com/community/tutorials/fuzzy-string-python
from fuzzywuzzy import fuzz

# define function
# input = mismatched word, output = og word, score, closest word
def get_similar(word,possibilities):
  score = 0
  match = ""
  for x in possibilities:
    s = fuzz.ratio(word, x)
    if s > score:
      score = s
      match = x

  print(f'{word} - {match}: {score}% similarity')

# run on all unmatched entries
for x in y:
  get_similar(x,gov_sect)
# Out:
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# Mushikir - Mushikiri: 94% similarity
# Pera - Ngera: 67% similarity
# Rusheshe - Rushashi: 75% similarity
# Kamanyenga - Kamabuye: 67% similarity
# Kibingo - Kibungo: 86% similarity
# Katabagema - Katabagemu: 90% similarity
# Kabukuba - Rwankuba: 62% similarity
# Nyagihinga - Nyagihanga: 90% similarity
# Gishari - Gishali: 86% similarity
# Gorwe - Gatore: 73% similarity
# Mwili - Mwiri: 80% similarity
# Buruhukioro - Buruhukiro: 95% similarity
# Buheta - Butare: 67% similarity
# Rerenge - Rurenge: 86% similarity
# Terimbere - Mageragere: 53% similarity
# Bwisìge - Bwisige: 86% similarity
# Rulindo - Ruli: 73% similarity
# Koza - Boneza: 60% similarity
# Gushali - Gishali: 86% similarity
# Ngarurira - Ngarama: 62% similarity
# Mulinga - Muringa: 86% similarity
# Cyobe - Kiyombe: 67% similarity
# Nkaka - Nkanka: 91% similarity
# Kabagari - Kabagali: 88% similarity
# Kamuragi - Karago: 71% similarity
# Giko - Gikonko: 73% similarity
# Gasakka - Gasaka: 92% similarity
# Gatsatagisozi - Gatsata: 70% similarity
# Cyingwa - Cyahinda: 67% similarity
# Rugamba - Ruramba: 86% similarity
# Rugalika - Rugarika: 88% similarity
# Nyirangarama - Ngarama: 74% similarity
# Gikheke - Giheke: 92% similarity
# Bushonyi - Mushonyi: 88% similarity
# Mutongo - Muhondo: 71% similarity
# Nyakabingo - Cyabingo: 78% similarity

# %%
# check to see how many cells don't match
btp_cell = df.Cell.unique()
gov_cell = names_codes.Cell.unique()

# %%
# now check if btp cells are in the gov dataset, excluding values with two cells
y = []
count = 0
for x in btp_cell:
  
  if "-" not in x and x is not "":
    count += 1
    if x not in gov_cell:
      y.append(x)
      #print(x)

print('number of non hyphenated cells in btp dataset',count)
print('number of unmatched cells in btp dataset',len(y))
# Out:
# number of non hyphenated cells in btp dataset 373
# number of unmatched cells in btp dataset 89

# %%
# find the misspellings
for x in y:
  get_similar(x,gov_cell)
# Out:
# Bit - Bitaba: 67% similarity
# Gihga - Gihanga: 83% similarity
# Rubilizi - Rubirizi: 88% similarity
# But - Buheta: 67% similarity
# Mparantima - Marantima: 95% similarity
# Nziranzira - Nziranziza: 90% similarity
# Nyamiha - Nyamihanda: 82% similarity
# Cygwa - Cyingwa: 83% similarity
# Katabagema - Katabagemu: 90% similarity
# Karushuga - Kamubuga: 71% similarity
# Gikana - Gikaya: 83% similarity
# Bayigurire - Bayigaburire: 91% similarity
# Rwikiro - Rwikiniro: 88% similarity
# Kib - Kibu: 86% similarity
# Burumba - Buruba: 92% similarity
# Kiruri - Kiruli: 83% similarity
# Cyamuhda - Cyamuhinda: 89% similarity
# Kyovu - Kiyovu: 91% similarity
# Rimbanya - Kimana: 71% similarity
# Rukungu - Mukungu: 86% similarity
# Bugambo - Bugamba: 86% similarity
# Mudugali - Mudugari: 88% similarity
# Bishyiga - Bisenga: 67% similarity
# Muni - Munazi: 80% similarity
# Gatembe - Gatete: 77% similarity
# Kagoya - Kagoma: 83% similarity
# Kirda - Kirwa: 80% similarity
# Nda - Ndago: 75% similarity
# Kabyiro - Kabyiniro: 88% similarity
# Nyamirga - Nyamiringa: 89% similarity
# Bukwashuli - Bukwashuri: 90% similarity
# Ruhga - Ruhanga: 83% similarity
# Nyya - Nyinya: 80% similarity
# Ngaruriye - Ngarurira: 78% similarity
# Nyabushgitwa - Nyabushingitwa: 92% similarity
# Nyarwa - Cyarwa: 83% similarity
# Gahumuriza - Gahumuliza: 90% similarity
# Rwarurema - Nyarurema: 78% similarity
# Kavuruga - Kamubuga: 75% similarity
# Kibgo - Kibingo: 83% similarity
# Agat - Agatare: 73% similarity
# Nyagat - Nyagatare: 80% similarity
# Kabushge - Kabushinge: 89% similarity
# Nyamiheha - Nyamihanda: 74% similarity
# Muhengeri - Mutengeri: 89% similarity
# Muta - Mutaho: 80% similarity
# Knge - Kagenge: 73% similarity
# Musama - Murama: 83% similarity
# Rugali - Bugali: 83% similarity
# Nyarushike - Nyarusazi: 74% similarity
# Nyamugali - Nyamugari: 89% similarity
# Kba - Kabare: 67% similarity
# Kngera - Karengera: 80% similarity
# Kyaga - Kinyaga: 83% similarity
# Kngere - Kabere: 67% similarity
# Mutengeli - Mutengeri: 89% similarity
# Nyiraruhuha - Nyaruka: 67% similarity
# Gat - Gati: 86% similarity
# Musega - Musenda: 77% similarity
# Gahuriro - Gacuriro: 88% similarity
# Ba - Basa: 67% similarity
# Kngeri - Karengeri: 80% similarity
# Bukanyana - Bukinanyana: 90% similarity
# Gihanika - Gihanga: 80% similarity
# Nyabirama - Nyamirama: 89% similarity
# Rukatsi - Rukatsa: 86% similarity
# Nyamiga - Nyamigina: 88% similarity
# Kdama - Kindama: 83% similarity
# Gahga - Gahanga: 83% similarity
# Kaniga - Kanoga: 83% similarity
# Nkgo - Nkingo: 80% similarity
# Kidogo - Kidomo: 83% similarity
# Mweya - Bweya: 80% similarity
# Gitongo - Gakingo: 71% similarity
# Rutaraga - Rutaraka: 88% similarity
# Gitda - Gitinda: 83% similarity
# Mibumbano - Mubumbano: 89% similarity
# Kadehero - Kadaho: 71% similarity
# Mutiwgoma - Mutiwingoma: 90% similarity
# Nyabisdu - Nyabisindu: 89% similarity
# Kabiraho - Kabihogo: 75% similarity
# Biteteri - Buteteri: 88% similarity
# Buhdure - Buhindure: 88% similarity
# Nyaka - Nyakiga: 83% similarity
# Shyororo - Shororo: 93% similarity
# Cyarub - Cyarubare: 80% similarity
# Nyakabgo - Nyakabingo: 89% similarity
# Runyya - Runyinya: 86% similarity
# Muga - Mbuga: 89% similarity

# %%
# check to see how many villages don't match
btp_vill = df.Village.unique()
gov_vill = names_codes.Village.unique()

# %%
# now check if btp villages are in the gov dataset, excluding values with two villages
y = []
count = 0
for x in btp_vill:
  
  if "-" not in x and x is not "":
    count += 1
    if x not in gov_vill:
      y.append(x)
      #print(x)

print('number of non hyphenated villages in btp dataset',count)
print('number of unmatched villages in btp dataset',len(y))
# Out:
# number of non hyphenated villages in btp dataset 40
# number of unmatched villages in btp dataset 6

# %%
# find the misspellings -> For Ping

for x in y:
  get_similar(x,gov_vill)
# Out:
# Mugesera - Bugesera: 88% similarity
# Cyamunganga - Cyamuganga: 95% similarity
# Akabaka - Akabaya: 86% similarity
# Ryakanyamiga - Ryakanyamiganda: 89% similarity
# Kaverano - Kaberano: 88% similarity
# Mwishyogwe - Mwishogwe: 95% similarity

# %%
df=df.replace({'Sector' : {'Mushikir': 'Mushikiri',
 'Pera':'Bugarama',
 'Rusheshe':'Masaka',
 'Kamanyenga': 'Nkanka',
 'Kibingo': 'Gihombo',
 'Katabagema':'Katabagem',
 'Kabukuba': 'Juru',
 'Nyagihinga': 'Nyagihanga',
 'Gishari': 'Rubaya',
 'Gorwe': 'Mata',
 "Mwili": 'Mwiri',
 'Buruhukioro': 'Buruhukiro', 'Rerenge': 'Rurenge',
 'Terimbere':'Nyundo',
 'Bwisìge': 'Bwisige',
 'Rulindo': 'Base',
 'Koza': 'Kazo',
 'Gushali': 'Gishali',
 'Ngarurira': 'Munini',
 'Mulinga': 'Muringa',
 'Cyobe': 'Nyamagabe',
 'Nkaka': 'Nkanka',
 'Kabagari': 'Kabagali',
 'Kamuragi': 'Tumba',
 'Giko':'Bushoki',
 'Gasakka': 'Gasaka', 'Cyingwa': 'Gitambi',
 'Rugamba': 'Ruganda',
 'Rugalika': 'Rugarika',
 'Nyirangarama': 'Bushoki',
 'Gikheke': 'Giheke',
 'Bushonyi': 'Mushonyi',
 'Mutongo': 'Macuba',
 'Nyakabingo': 'Macuba'}})

df[df['Sector']=='Kazo']
# Out:
#     Country          Province  ...                 Community_served Dist_ID
# 111  Rwanda  Eastern Province  ...                 Umukamba              56
# 126  Rwanda  Eastern Province  ...         Gahurire  Kinyonzo            56
# 129  Rwanda  Eastern Province  ...         Kinyonzo  Gahurire            56
# 153  Rwanda  Eastern Province  ...  Birenga  Kinyonzo  Gahuriro          56
# 429  Rwanda  Eastern Province  ...            Umukamba cell              56
# 758  Rwanda  Eastern Province  ...                 Gahuriro              56
#
# [6 rows x 25 columns]

# %%
df=df.replace({'Cell': {'Bit': 'Bitare',
 'Gihga': 'Gihinga', 
 'But': 'Butare',  
 'Gikana': 'Kabukuba',  
 'Kib': 'Kibare',
 'Burumba': 'Burunga',  
 'Kyovu': 'Kinyovu',
 'Rimbanya': 'Gorwe',
 'Rukungu': 'Karukungu',  
 'Bishyiga': 'Byimana',
 'Muni': 'Munini',
 'Kagoya': 'Kigoya',
 'Kirda': 'Kirinda',
 'Nda': 'Ninda',    
 'Ruhga': 'Ruhinga', 
 'Nyarwa': 'Nyarwina',  
 'Rwarurema': 'Bwisige',  
 'Nyamiheha': 'Kagarama',
 'Muhengeri': 'Mutandi',
 'Muta': 'Mutanda',
 'Knge': 'Kirenge',
 'Musama': 'Musenda',
 'Rugali': 'Gacundura',
 'Nyarushike': 'Cyobe',  
 'Kba': 'Kareba',  
 'Kngere': 'Karengera',  
 'Nyiraruhuha': 'Nyamugari',
 'Gat': 'Gatare',
 'Musega': 'Kivugiza',
 'Gahuriro': 'Gahurire',
 'Ba': 'Banda',  
 'Gihanika': 'Ihanika',
 'Nyabirama': 'Nyarurama',  
 'Gahga': 'Gahinga',
 'Kaniga': 'Bugomba',  
 'Kidogo': 'Budakiranya',
 'Mweya': 'Gahunga',
 'Gitongo': 'Mbogo',
 'Rutaraga': 'Mutego',  
 'Kadehero': 'Rubona',  
 'Kabiraho': 'Bumba',  
 'Nyaka': 'Nyakina',  
 'Muga': 'Mugina'}})

# %%
# now need to check the hyphenated values
# need to modify this function so that it checks for words inside of strings
def get_similar_hyphenated(word,possibilities):
  score = 0
  score2 = 0
  match = ""
  match2 = ""
  for x in possibilities:
    s = fuzz.partial_ratio(word, x)
    if s > score:
      score2 = score
      score = s
      match2 = match
      match = x

    elif score == 100 and s == 100:
      score2 = s
      match2 = x

  if score2 < 100:
    #print(f'{word} - {match}-{match2}: {score}-{score2}% similarity')
    pass

  return score, score2, match, match2, word

# %%
# now check if btp sectors are in the gov dataset, focusing on values with two or more sectors
y = []
count = 0
for x in btp_sect:
  if "-" in x and x is not "":
    count += 1
    if x not in gov_sect:
      y.append(x)

print('number of hyphenated sectors in btp dataset',count)
print('number of unmatched sectors in btp dataset',len(y))
# Out:
# number of hyphenated sectors in btp dataset 264
# number of unmatched sectors in btp dataset 264

# %%
for x in y:
  get_similar_hyphenated(x,gov_sect)

# %%
# now check if btp cells are in the gov dataset, focusing on values with two or more cells
y = []
count = 0
for x in btp_cell:
  if "-" in x and x is not "":
    count += 1
    if x not in gov_cell:
      y.append(x)

print('number of hyphenated cells in btp dataset',count)
print('number of unmatched cells in btp dataset',len(y))
# Out:
# number of hyphenated cells in btp dataset 654
# number of unmatched cells in btp dataset 654

# %%
a = names_codes[names_codes['District']=='Ngoma'][names_codes['Sector']=='Karembo']
a['Cell'].unique()
#names_codes[names_codes['Cell']=='Congo-nil']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# array(['Akaziba', 'Karaba', 'Nyamirambo'], dtype=object)

# %%
df.loc[[1454]]
# Out:
#      Country          Province  ...                Community_served Dist_ID
# 1454  Rwanda  Eastern Province  ...  Kiyovu  Nyarucyamo  Ruhita          51
#
# [1 rows x 25 columns]

# %%
# Move one of the values into the village column when theres a village value more accurate than the cell value

for i in df.index:
  x = df.Cell[i]
  cellscore1, cellscore2, cellmatch1, cellmatch2, word = get_similar_hyphenated(x,gov_cell)
  villscore1, villscore2, villmatch1, villmatch2, word = get_similar_hyphenated(x,gov_vill)
  if villscore1 > cellscore1:
    # if theres a gov village thats a perfect match then move the value into the village column
    if villscore1 == 100:
      df.loc[i, 'Cell'] = villmatch1 
      x = df.loc[i, 'Cell'] = df['Cell'][i].replace(villmatch1,"")
      # if more than one "-", it has more than 2 values and we need to handle manually
      if "-" in x[1:-2]:
        print(i)
        print(f'{word} - {cellmatch1}-{villmatch1}: {cellscore1}-{villscore1}% similarity')
      # otherwise clean out the dashes
      else:
        df.loc[i, 'Cell'] = df['Cell'][i].replace("-","")

    # if theres not a perfect match then handle manually
    else:
      print(i)
      print(f'{word} - {cellmatch1}-{villmatch1}: {cellscore1}-{villscore1}% similarity')
# Out:
# 49
# Kagesa-Mitsdo - Kagasa-Mitsindo: 83-86% similarity
# 53
# Nyabit-Nyabayamo - Kabaya-Nyabayama: 83-89% similarity
# 123
# Karushuga - Ruhunga-Karuhuga: 77-88% similarity
# 124
# Gasga-Uwkiko - Basa-Uwinkiko: 75-86% similarity
# 177
# Cyamuhda - Cyahinda-Cyamuhabura: 75-88% similarity
# 305
# Kabyiro - Gabiro-Kabirombe: 83-86% similarity
# 480
# Git-Nyabit - Nyabimata-Nyabiti: 80-92% similarity
# 496
# Kabushge - Cyabusheshe-Kabusheja: 75-88% similarity
# 705
# Git-Mugereki - Mugera-Mugereke: 83-88% similarity
# 801
# Bukanyana - Kanyana-Akanyana: 86-88% similarity
# 1210
# Nyabisdu - Nyabibugu-Nyabishunguru: 75-88% similarity
# 1276
# Buhdure - Sure-Buhuru: 75-83% similarity
# 1302
# Gat-Kirja - Kirwa-Kirinja: 80-83% similarity
# 1331
# Buhdure - Sure-Buhuru: 75-83% similarity
# 1378
# Karushuga - Ruhunga-Karuhuga: 77-88% similarity
# 1429
# Nyakabgo - Nyabigoma-Nyakagoma: 75-88% similarity
# 1454
# Runyya - Cyeya-Runyanzige: 67-83% similarity

# %%
# manually fix these cells by checking the matching values to see which fits the rest of the data in the row
# 29
# Nyagihika - Nyagihunika-Nyagihima: 78-89% similarity
df.loc[29, 'Cell'] = 'Nyagihunika'
df.loc[29, 'Village'] = 'Nyakajuri'

# 49
# Kagesa-Mitsdo - Kagasa-Mitsindo: 83-86% similarity
df.loc[49, 'Cell'] = 'Kagasa'
df.loc[49, 'Village', ] = 'Mitsindo'

# 53
# Nyabit-Nyabayamo - Kabaya-Nyabayama: 83-89% similarity
df.loc[53, 'Cell'] = 'Nyabitare'
df.loc[53, 'Village'] = 'Nyabayama'

# 123
# Karushuga - Ruhunga-Karuhuga: 77-88% similarity
df.loc[123, 'Cell'] = 'Karushuga?'
df.loc[123, 'Village'] = '?'

# 124
# Gasga-Uwkiko - Basa-Uwinkiko: 75-86% similarity
df.loc[124, 'Cell'] = 'Rwempasha'
df.loc[124, 'Village'] = 'Uwinkiko'

# 177
# Cyamuhda - Cyahinda-Cyamuhabura: 75-88% similarity
df.loc[177, 'Cell'] = 'Cyamuhinda'
df.loc[177, 'Village'] ='Rugaragara'

# 305
# Kabyiro - Gabiro-Kabirombe: 83-86% similarity Kabyiniro
df.loc[305, 'Cell'] =  'Kabyiniro'
df.loc[305, 'Village'] = 'Mugeshi'

# 480
# Git-Nyabit - Nyabimata-Nyabiti: 80-92% similarity
df.loc[480,'Cell'] =  'Gitare'
df.loc[480, 'Village'] ='Nyabitare'

# 496
# Kabushge - Cyabusheshe-Kabusheja: 75-88% similarity
df.loc[496, 'Cell'] = 'Kabushinge'
df.loc[496, 'Village'] = 'Rwamigimbu'

# 705
# Git-Mugereki - Mugera-Mugereke: 83-88% similarity
df.loc[705, 'Cell'] = 'Gitare'
df.loc[705, 'Village'] = 'Mugereke	'

# 801
# Bukanyana - Kanyana-Akanyana: 86-88% similarity
df.loc[801, 'Cell'] = 'Bukinanyana'
df.loc[801, 'Village'] = 'Bugarama'

# 1210
# Nyabisdu - Nyabibugu-Nyabishunguru: 75-88% similarity
df.loc[1210, 'Cell'] =  'Nyabisindu'
df.loc[1210, 'Village'] = 'Kanyege'
df.loc[1210, 'Community Served 1'] = 'Kanyege'

# 1276
# Buhdure - Sure-Buhuru: 75-83% similarity
df.loc[1276, 'Cell'] = 'Buhindure'
df.loc[1276, 'Village'] = 'Burambo'

# 1301
# Congo-Nile-Mucyebera-Mushubati-Kabiraho - Congo-nil-Kabiraho: 89-100% similarity
df.loc[1301, 'Cell'] = 'Congo-nil'
df.loc[1301, 'Village'] = 'Mukebera'
df.loc[1301, 'Community Served 1'] = 'Mukebera'

# 1302
# Gat-Kirja - Kirwa-Kirinja: 80-83% similarity
df.loc[1302, 'Cell'] =  'Gatare'
df.loc[1302, 'Village'] = 'Kirinja'

# 1305
# Rurars-Kaboneye - Kabona-Kabo: 83-100% similarity
df.loc[1305, 'Cell'] = 'Rurara'
df.loc[1305, 'Village'] = 'Kaboneye'

# 1331
# Buhdure - Sure-Buhuru: 75-83% similarity
df.loc[1331, 'Cell'] = 'Rukaragata'
df.loc[1331, 'Village'] = 'Nganzo'

# 1334
# Congo-Nile-Nkwiro-Mucyebera - Congo-nil-Nkwiro: 89-100% similarity
df.loc[1334, 'Cell'] = 'Congo-nil'
df.loc[1334, 'Village'] = 'Nkwiro'

# 1378
# Karushuga - Ruhunga-Karuhuga: 77-88% similarity
df.loc[1378, 'Cell'] = 'Karushuga?'
df.loc[1378,'Village'] = '?'

# 1429
# Nyakabgo - Nyabigoma-Nyakagoma: 75-88% similarity
df.loc[1429, 'Cell'] = 'Nyakabingo'
df.loc[1429, 'Village'] = 'Rumamfu'

# 1454
# Runyya - Cyeya-Runyanzige: 67-83% similarity
df.loc[1454, 'Cell'] = 'Runyinya'
df.loc[1454, 'Village'] = 'Kiyovu'


# fix mismatched villages that Ping couldnt find 
df.loc[93, 'Cell'] = 'Marantima'
df.loc[93, 'Village'] = 'Munyegera'

df.loc[344, 'Sector'] = 'Karembo'
df.loc[344, 'Cell'] = 'Nyamirambo'
df.loc[344, 'Village'] = 'Murambi'

# %%
df.tail()
# Out:
#      Country  ... Dist_ID
# 1467  Rwanda  ...      28
# 1468  Rwanda  ...      51
# 1469  Rwanda  ...      35
# 1470  Rwanda  ...      35
# 1471  Rwanda  ...      55
#
# [5 rows x 25 columns]

# %%
# Assign IDs to sectors
# create an ID key for the sector values
sect_key = names_codes[['District','Sector','Sect_ID']].drop_duplicates('Sect_ID')

cell_key = names_codes[['District','Sector','Cell','Sect_ID','Cell_ID']].drop_duplicates('Cell_ID')

# %%
sect_key[sect_key.Sector == 'Murambi']
# Out:
#      District   Sector  Sect_ID
# 512   Rulindo  Murambi     4111
# 518   Rulindo  Murambi     4144
# 7934  Karongi  Murambi     3106
# 8739  Gatsibo  Murambi     5309

# %%
# check if there are any duplicate sectors in a single district
repeats = sect_key.Sector.value_counts()[:30]
print(repeats.index)
for x in repeats.index:
  #print(sect_key[sect_key.Sector == x].District.value_counts())
  r = sect_key[sect_key.Sector == x].District.value_counts()[0]
  if  r > 1:
    print(x)
# Out:
# Index(['Remera', 'Murambi', 'Kageyo', 'Muganza', 'Karama', 'Ngoma', 'Kigoma', 'Murama', 'Rukomo', 'Nemba', 'Nyange', 'Kinihira', 'Muko', 'Tumba', 'Nyamiyaga', 'Kigarama', 'Kibirizi', 'Mukarange', 'Kinazi', 'Rwimbogo', 'Ruhango', 'Mbazi', 'Murundi', 'Nyarugenge', 'Musha', 'Busasamana', 'Nyagisozi', 'Rugarama', 'Cyanika', 'Mukura'], dtype='object')
# Murambi

# %%
# drop confusing/irrelevant duplicate marambi id
sect_key = sect_key.drop(518)
sect_key[sect_key.Sector == 'Murambi']
# Out:
#      District   Sector  Sect_ID
# 512   Rulindo  Murambi     4111
# 7934  Karongi  Murambi     3106
# 8739  Gatsibo  Murambi     5309

# %%
# so now we've taken care of the instances where villscore1 > cellscore1
# This function automatically identifies the cells in the given Sector and District and picks a name 
# that has a leveshtein ratio above 70. If there is none then it returns it to be fixed manually
# Note: This function only covers the entries without a dash(-)

for i in df.index:
  x = df.Cell[i]
  cellscore1, cellscore2, cellmatch1, cellmatch2, word = get_similar_hyphenated(x,gov_cell)
  villscore1, villscore2, villmatch1, villmatch2, word = get_similar_hyphenated(x,gov_vill)
  
  if 100 > cellscore1 and x is not "" and "-" not in x:

    # search the dataset by district and sector, then loop through the cell values and pick whatever's closest above 70% simililarity
    possible_rows = names_codes[names_codes['District']==df.District[i]][names_codes['Sector']==df.Sector[i]]
    unique_possible_cells = possible_rows['Cell'].unique()
    high = 0
    hiword = ""
    for cell in unique_possible_cells:
      score = fuzz.ratio(cell, x)
      if score > high:
        high = score
        hiword = cell

    if high > 70:
      df.loc[i, 'Cell'] = hiword
    
    else:
      print(i)
      print( f'{word} - {hiword}: {high}% similarity')
  
  #elif
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-af9abdb0a3c8> in <module>()
#       7   x = df.Cell[i]
#       8   cellscore1, cellscore2, cellmatch1, cellmatch2, word = get_similar_hyphenated(x,gov_cell)
# ----> 9   villscore1, villscore2, villmatch1, villmatch2, word = get_similar_hyphenated(x,gov_vill)
#      10
#      11   if 100 > cellscore1 and x is not "" and "-" not in x:
#
# <ipython-input-37-e056f58aa3cc> in get_similar_hyphenated(word, possibilities)
#       7   match2 = ""
#       8   for x in possibilities:
# ----> 9     s = fuzz.partial_ratio(word, x)
#      10     if s > score:
#      11       score2 = score
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      27         if args[0] == args[1]:
#      28             return 100
# ---> 29         return func(*args, **kwargs)
#      30     return decorator
#      31
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      45         if len(args[0]) == 0 or len(args[1]) == 0:
#      46             return 0
# ---> 47         return func(*args, **kwargs)
#      48     return decorator
#      49
#
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py in partial_ratio(s1, s2)
#      60
#      61         m2 = SequenceMatcher(None, shorter, long_substr)
# ---> 62         r = m2.ratio()
#      63         if r > .995:
#      64             return 100
#
# /usr/lib/python3.6/difflib.py in ratio(self)
#     643
#     644         matches = sum(triple[-1] for triple in self.get_matching_blocks())
# --> 645         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     646
#     647     def quick_ratio(self):
#
# /usr/lib/python3.6/difflib.py in _calculate_ratio(matches, length)
#      38 def _calculate_ratio(matches, length):
#      39     if length:
# ---> 40         return 2.0 * matches / length
#      41     return 1.0
#      42
#
# KeyboardInterrupt:

# %%
# pings corrections
pd.set_option('display.max_rows', 5000)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.width', 1000)

# %%
# create a sector_id, cell_id, and village_id column to match the cell values

df['Sector_ID'] = ""
df['Cell_ID'] = ""
df['Village_ID'] = ""

# %%
df = df.drop('Sect_ID',axis=1)
print(df.head())
# Out:
#   Country           Province District   Sector               Cell Bridge Site Name Project Stage Project Sub-Stage Project Code Bridge Type  Span (m) GPS (Latitude) GPS (Longitude)  Individuals Directly Served                  Form: Form Name Community Served 1   Community Served 2 Community Served 3 Community Served 4 Community Served 5     CaseSafeID Form Bridge Opportunity: Opportunity ID Village                                   Community_served  Dist_ID Cell_ID Sector_ID Village_ID
# 0  Rwanda   Western Province   Rusizi   Giheke           Gakomeye             Buzi      Rejected         Technical      1014107   Suspended       0.0       -2.42056         28.9662                          0.0  Project Assessment - 2018.10.29               Buzi               Kabuga           Kagarama            Gacyamo            Gasheke  a1if1000002e51bAAA                    006f100000d1fk1                   Buzi  Kabuga  Kagarama  Gacyamo  Gasheke       36
# 1  Rwanda   Western Province   Rusizi   Giheke           Gakomeye        Kamigisha      Rejected         Technical      1014106   Suspended       0.0       -2.42486         28.9573                          0.0  Project Assessment - 2018.10.29             Kabuga                 Buzi  Gacyamo - Gasheke           Kagarama             Kanoga  a1if1000002e51WAAQ                    006f100000d1fjw          Kabuga  Buzi  Gacyamo - Gasheke  Kagarama  Kanoga       36
# 2  Rwanda  Northern Province  Rulindo   Buyoga  Gahororo-Gipfundo         Gipfundo      Rejected         Technical      1007651   Suspended       8.0       -1.72053         30.0812                          0.0   Project Assessment - 2018.8.11           Gapfundo  Rusabira ( Gicumbi)             Merezo           Minanire          Karutongo  a1if10000025nz8AAA                    006f100000a86I3          Gapfundo  Rusabira ( Gicumbi)  Merezo  Minanir...       41
# 3  Rwanda  Northern Province  Gicumbi   Kageyo  Kabuga-Gatobotobo       Nyarubande      Rejected                        1012493       Other       0.0       -1.65595         30.0788                          0.0   Project Assessment - 2018.8.11                                                                                                   a1if10000025nzDAAQ                    006f100000cPpL8                                                                  45
# 4  Rwanda  Southern Province  Kamonyi  Kayenzi              Kirwa           Gisizi    Identified         Requested      1014318   Suspended       0.0       -1.87087         29.8777                          0.0  Project Assessment - 2018.11.15             Gisizi            Nyabitare                                                           a1if1000002gMwRAAU                    006f100000eescb                                    Gisizi  Nyabitare             28

# %%
# for each value we need to go through and check if the gov values are in these values,
# then check to see which district it matches
for i in df.index:
  x = df.Sector[i]
  dist = df.District[i]

  if x in sect_key.Sector.values:

    # need to check the right district to determine which ID it should get
    if dist in sect_key[sect_key.Sector == x].District.values:

      sect_row = sect_key[sect_key.District == dist][sect_key.Sector == x]

      # check to make sure there is only one corresponding ID
      if len(sect_row) == 1:
        df.loc[i, 'Sector_ID'] = sect_row.Sect_ID.item()
        
      else:
        print(i,'sect_id error',sect_id)
      
    # this column has already been cleaned, so we try to search by the bridge site name and if nothing is found
    # this is an erroneous/unmatchable entry and should be marked accordingly
    else:
          poss_village = names_codes[names_codes.District == dist][names_codes['Village'] == df.loc[i,'Bridge Site Name']]
          
          if len(poss_village) == 1:
            df.loc[i,'Sector_ID'] = poss_village.Sect_ID.item()
            df.loc[i,'Cell_ID'] = poss_village.Cell_ID.item()
            df.loc[i,'Village_ID'] = poss_village.Vill_ID.item()
          
          else:
            # unidentifiable, add '?'
            df.loc[i,'Cell'] = f'{df.loc[i,"Cell"]}?'

  # now cover the hyphenated values - The cell values must also be identified and matched in this part of the function because the hyphenated
  # values list two potential sectors. We need to identify the sector that the government has the corresponding cell and village listed under
  # in order to correctly match the ids
  elif "-" in x:

    # check the sectors values in the corresponding district, get top two fuzzy sector matches, 
    # check the top match for cell matches, if no matching cells then check the second match for cell matches
    poss_sects = names_codes[names_codes.District == dist]
    poss_sects_list = poss_sects['Sector'].unique()
    sectscore1, sectscore2, sectmatch1, sectmatch2, word = get_similar_hyphenated(x,poss_sects_list)

    # here we're checking to see if the cell listed in this entry matches any of the government cells listed
    # under the first sector match
    if sectscore1 > 70:
      poss_cells = names_codes[names_codes.District == dist][names_codes.Sector == sectmatch1]
      poss_cells_list = poss_cells['Cell'].unique()

      cellscore1, cellscore2, cellmatch1, cellmatch2, word = get_similar_hyphenated(df.Cell[i],poss_cells_list)

      # if there is a match, we set the sector and cell IDS accordingly
      if cellscore1 > 85:
        matching_row = cell_key[cell_key.District == dist][cell_key.Sector == sectmatch1][cell_key.Cell == cellmatch1]
    
        df.loc[i,'Sector_ID'] = matching_row.Sect_ID.item()
        df.loc[i,'Cell_ID'] = matching_row.Cell_ID.item()

      # if the first value did not match, and the second sector value is potentially valid, then check to see
      # if theres a cell that matches the second sector value
      elif sectscore2 > 70:
        poss_cells = names_codes[names_codes.District == dist][names_codes.Sector == sectmatch2]
        poss_cells_list = poss_cells['Cell'].unique()

        cellscore1, cellscore2, cellmatch1, cellmatch2, word = get_similar_hyphenated(df.Cell[i],poss_cells_list)

        # if there is a match, we set the sector and cell IDS accordingly
        if cellscore1 > 85:
          matching_row = cell_key[cell_key.District == dist][cell_key.Sector == sectmatch2][cell_key.Cell == cellmatch1]

          if len(matching_row) == 1:
            df.loc[i,'Sector_ID'] = matching_row.Sect_ID.item()
            df.loc[i,'Cell_ID'] = matching_row.Cell_ID.item()

          else:
            print('error in s2mrow:', matching_row)

        # otherwise we try to search by the bridge site name and set values accordingly
        else:
          poss_village = names_codes[names_codes.District == dist][names_codes['Village'] == df.loc[i,'Bridge Site Name']]
          
          if len(poss_village) == 1:
            df.loc[i,'Sector_ID'] = poss_village.Sect_ID.item()
            df.loc[i,'Cell_ID'] = poss_village.Cell_ID.item()
            df.loc[i,'Village_ID'] = poss_village.Vill_ID.item()
          
          else:
            # unidentifiable, add '?'
            df.loc[i,'Cell'] = f'{df.loc[i,"Cell"]}?'

      # else theres no matching cell for either sector so try to search by bridge site name
      else:
          #print('no sector-cell matches',i, names_codes[names_codes.District == dist][names_codes['Village'] == df.loc[i,'Bridge Site Name']])
          poss_village = names_codes[names_codes.District == dist][names_codes['Village'] == df.loc[i,'Bridge Site Name']]
          
          if len(poss_village) == 1:
            df.loc[i,'Sector_ID'] = poss_village.Sect_ID.item()
            df.loc[i,'Cell_ID'] = poss_village.Cell_ID.item()
            df.loc[i,'Village_ID'] = poss_village.Vill_ID.item()

          elif len(poss_village) > 1:
            print('no sector cell match')
            print('Dist', dist)
            print('index:',i, poss_village)
          
          else:
            # unidentifiable, add '?'
            df.loc[i,'Cell'] = f'{df.loc[i,"Cell"]}?'


  else:
    #identify leveshtein distance and try to match manually
    if '?' not in x:
      hi = 0
      himatch = ""
      for sect in sect_key.Sector.values:
        score = fuzz.ratio(x,sect)
        if score > hi:
          hi = score
          himatch = sect

      print('Sector value is not known and is not hyphenated:', i, x, himatch, hi)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:49: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:56: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:64: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:71: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:82: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:96: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:49: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:64: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:82: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:71: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:56: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:96: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# no sector cell match
# Dist Gakenke
# index: 316       Prov_ID      Province  Dist_ID District  Sect_ID   Sector  Cell_ID     Cell   Vill_ID Village Status   FID
# 3956        4  Amajyaruguru       42  Gakenke     4213  Muhondo   421305     Huro  42130504  Kabuga  Rural  9084
# 8693        4  Amajyaruguru       42  Gakenke     4211   Minazi   421103  Murambi  42110302  Kabuga  Rural  8868
# 9423        4  Amajyaruguru       42  Gakenke     4201  Busengo   420106   Mwumba  42010601  Kabuga  Rural  8843
# 9854        4  Amajyaruguru       42  Gakenke     4212  Mugunga   421204  Nkomane  42120401  Kabuga  Rural  9054

# %%
for i in df.index:
  cell = df.Cell[i]
  sect_id = df.Sector_ID[i]

  if x in cell_key.Cell.values:
    # need to check the right sector_id to determine which ID it should get
    if sect_id in cell_key[cell_key.Cell == cell].Sect_ID.values:
      cell_row = cell_key[cell_key.Sect_ID == sect_id][cell_key.Cell == cell]
      #match ids
      print('MATCH')

    else:
      print('f')

  else:
    print('f')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   import sys
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# f
# f
# f
# f
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# f
# MATCH
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# f
# f
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# f
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# f
# MATCH
# f
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# MATCH
# f
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# f
# f
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# MATCH
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# f
# MATCH
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# f
# MATCH
# f
# MATCH
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# f
# f
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# f
# MATCH
# f
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# MATCH
# f
# f
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# f
# MATCH
# MATCH
# f
# MATCH
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# MATCH
# f
# f
# MATCH
# f
# f
# MATCH
# MATCH
# f
# f
# f
# MATCH
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# f
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# f
# f
# MATCH
# f
# f
# f
# MATCH
# f
# MATCH
# f
# MATCH
# f
# MATCH
# MATCH
# f
# MATCH
# f
# f
# f
# f
# f
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# f
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# MATCH
# f
# f
# f
# f
# f
# MATCH
# f

# %%
names_codes[names_codes.District == 'Rulindo'][names_codes['Sector'] == 'Murambi']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       Prov_ID      Province  Dist_ID District  Sect_ID   Sector  Cell_ID       Cell   Vill_ID     Village Status   FID
# 512         4  Amajyaruguru       41  Rulindo     4111  Murambi   411101    Bubangu  41110101     Gashubi  Rural  8700
# 513         4  Amajyaruguru       41  Rulindo     4111  Murambi   411101    Bubangu  41110102     Karambo  Rural  8707
# 514         4  Amajyaruguru       41  Rulindo     4111  Murambi   411101    Bubangu  41110103       Karwa  Rural  8714
# 515         4  Amajyaruguru       41  Rulindo     4111  Murambi   411101    Bubangu  41110104     Mayange  Rural  8721
# 516         4  Amajyaruguru       41  Rulindo     4111  Murambi   411101    Bubangu  41110105   Nyagisozi  Rural  8729
# 517         4  Amajyaruguru       41  Rulindo     4111  Murambi   411101    Bubangu  41110106      Rebero  Rural  8737
# 518         4  Amajyaruguru       41  Rulindo     4144  Murambi   411101    Bubangu  41110107     Ruhunga  Rural  8745
# 519         4  Amajyaruguru       41  Rulindo     4144  Murambi   411101    Bubangu  41110108        Taba  Rural  8753
# 3132        4  Amajyaruguru       41  Rulindo     4111  Murambi   411102      Gatwa  41110201     Agatare  Rural  8761
# 3133        4  Amajyaruguru       41  Rulindo     4111  Murambi   411102      Gatwa  41110202    Akarambi  Rural  8768
# 3134        4  Amajyaruguru       41  Rulindo     4111  Murambi   411102      Gatwa  41110203     Amataba  Rural  8774
# 3135        4  Amajyaruguru       41  Rulindo     4111  Murambi   411102      Gatwa  41110204      Gisiza  Rural  8777
# 3136        4  Amajyaruguru       41  Rulindo     4111  Murambi   411102      Gatwa  41110205      Kabeza  Rural  8783
# 3137        4  Amajyaruguru       41  Rulindo     4111  Murambi   411102      Gatwa  41110206     Karambo  Rural  8787
# 3138        4  Amajyaruguru       41  Rulindo     4111  Murambi   411102      Gatwa  41110207    Kigarama  Rural  8790
# 8001        4  Amajyaruguru       41  Rulindo     4111  Murambi   411103  Mugambazi  41110303      Gahama  Rural  8408
# 8002        4  Amajyaruguru       41  Rulindo     4111  Murambi   411103  Mugambazi  41110304    Gashinge  Rural  8412
# 8003        4  Amajyaruguru       41  Rulindo     4111  Murambi   411103  Mugambazi  41110305    Kigarama  Rural  8417
# 8004        4  Amajyaruguru       41  Rulindo     4111  Murambi   411103  Mugambazi  41110306  Nyarurembo  Rural  8423
# 8005        4  Amajyaruguru       41  Rulindo     4111  Murambi   411103  Mugambazi  41110307        Ruri  Rural  8429
# 8006        4  Amajyaruguru       41  Rulindo     4111  Murambi   411103  Mugambazi  41110301     Amahoro  Rural  8793
# 8007        4  Amajyaruguru       41  Rulindo     4111  Murambi   411103  Mugambazi  41110302      Buliza  Rural  8795
# 9276        4  Amajyaruguru       41  Rulindo     4111  Murambi   411104      Mvuzo  41110401       Iraro  Rural  8435
# 9277        4  Amajyaruguru       41  Rulindo     4111  Murambi   411104      Mvuzo  41110402      Kabeza  Rural  8442
# 9278        4  Amajyaruguru       41  Rulindo     4111  Murambi   411104      Mvuzo  41110403      Kabuga  Rural  8450
# 9279        4  Amajyaruguru       41  Rulindo     4111  Murambi   411104      Mvuzo  41110404    Munyinya  Rural  8455
# 9280        4  Amajyaruguru       41  Rulindo     4111  Murambi   411104      Mvuzo  41110405      Mutabo  Rural  8461
# 9281        4  Amajyaruguru       41  Rulindo     4111  Murambi   411104      Mvuzo  41110406      Ntyaba  Rural  8467
# 9282        4  Amajyaruguru       41  Rulindo     4111  Murambi   411104      Mvuzo  41110407      Rurama  Rural  8476

# %%
# now need to modify the function so that "?" are inserted where we dont know and values are updated where we do

# %%
# these are the fixes for the hyphenated sectors that did not have a match in the cell column

df.loc[62, 'Sector'] = 'Gahengeri'
df.loc[62, 'Cell'] = 'Runyinya'
df.loc[62, 'Village'] = 'Karambo'

df.loc[277, 'Sector'] = 'Remera'
df.loc[277, 'Cell'] = 'Kinunga'
df.loc[277, 'Village'] = 'Murambi'

df.loc[492, 'Sector'] = 'Kigoma-Maraba?'
df.loc[492, 'Cell'] = '?'
df.loc[492, 'Village'] = '?'

df.loc[549, 'Sector'] = 'Kibeho-Muganza'
df.loc[549, 'Cell'] = '?'
df.loc[549, 'Village'] = '?'

df.loc[556, 'Sector'] = 'Murambi'
df.loc[556, 'Cell'] = 'Mugambazi'
df.loc[556, 'Village'] = 'Gahama'

df.loc[979, 'Sector'] = 'Ruhuha'
df.loc[979, 'Cell'] = 'Kindama'
df.loc[979, 'Village'] = 'Kibaza'

df.loc[454, 'Sector_ID'] = 241305
df.loc[454, 'Cell'] = 'Nyangazi'
df.loc[454, 'Cell_ID'] = 241305
df.loc[454, 'Village'] = 'Kanyiramana'
df.loc[454, 'Village_ID'] = 2995

df.loc[511, 'Sector'] = 'Mahembe'
df.loc[511, 'Cell'] = 'Nyagatare'
df.loc[511, 'Village'] = 'Karambo'

df.loc[703, 'Sector'] = 'Muyira'
df.loc[703, 'Cell'] = 'Migina'
df.loc[703, 'Village'] = 'Kinyana'

df.loc[709, 'Sector'] = 'Muyira'
df.loc[709, 'Cell'] = 'Migina'
df.loc[709, 'Village'] = 'Kinyana'

df.loc[726, 'Village'] = 'Karwa'	

df.loc[1209, 'Sector'] = 'Mbazi'
df.loc[1209, 'Cell'] = 'Mutiwingoma'
df.loc[1209, 'Village'] = 'Gatwa'

df.loc[1470, 'Sector'] = 'Muhororo'
df.loc[1470, 'Cell'] = 'Mubuga'
df.loc[1470, 'Village'] = 'Gasovu'

df.loc[243, 'Sector'] = 'Rwaza'
df.loc[243, 'Cell'] = 'Bumara'
df.loc[243, 'Village'] = 'Kavumu'

df.loc[316, 'Sector'] = 'Rongi-Mataba?'
df.loc[316, 'Cell'] = 'Kabuga-Muhororo?'
df.loc[316, 'Village'] = 'Kabuga?'

df.loc[337, 'Sector'] = 'Rukira'
df.loc[337, 'Cell'] = 'Nyinya'
df.loc[337, 'Village'] = 'Ruhama'

df.loc[457, 'Sector'] = 'Mbazi'
df.loc[457, 'Cell'] = 'Ngambi'
df.loc[457, 'Village'] = 'Munanira'

df.loc[622, 'Sector'] = 'Jomba'
df.loc[622, 'Cell'] = 'Gasiza'
df.loc[622, 'Village'] = 'Gahama'

df.loc[773, 'Sector'] = 'Kanyinya'
df.loc[773, 'Cell'] = 'Nyamweru'
df.loc[773, 'Village'] = 'Gatare'

df.loc[1221, 'Sector'] = 'Cyanika'
df.loc[1221, 'Cell'] = 'Gitega'
df.loc[1221, 'Village'] = 'Gitega'

# %%
# these are the fixes for the Sectors that were misspelled or entered in the wrong column
df=df.replace({'Sector': {'Katabagem': 'Katabagemu',  'Mageragere': 'Mageregere'}})

df.loc[273, 'Sector'] = 'Gakenke'
df.loc[273, 'Cell'] = 'Buheta'

df.loc[574, 'Sector'] = 'Mushubi'

df.loc[892, 'Sector'] = 'Gisozi'
df.loc[892, 'Cell'] = 'Ruhango'
df.loc[892, 'Village'] = 'Ntora'

# %%
# for these, we really just need the ids, so lets search the hyphenated values and identify the correct cell ID
# once we've identified the ID we can search the entries with the same ID for corresponding villages

for i in df.index:
  x = df.Cell[i]
  cellscore1, cellscore2, cellmatch1, cellmatch2, word = get_similar_hyphenated(x,gov_cell)
  villscore1, villscore2, villmatch1, villmatch2, word = get_similar_hyphenated(x,gov_vill)
  
  if 100 > cellscore1 and 100 > cellscore 2 and x is not "" and "-" in x:

    # search the dataset by district and sector, then loop through the cell values and pick whatever's closest above 70% simililarity
    possible_rows = names_codes[names_codes['District']==df.District[i]][names_codes['Sector']==df.Sector[i]]
    unique_possible_cells = possible_rows['Cell'].unique()
    high = 0
    hiword = ""
    for cell in unique_possible_cells:
      score = fuzz.ratio(cell, x)
      if score > high:
        high = score
        hiword = cell

    if high > 70:
      df.loc[i, 'Cell'] = hiword
    
    else:
      print(i)
      print( f'{word} - {cellmatch1}-{villmatch1}: {cellscore1}-{villscore1}% similarity')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# 118
# Katabagema - Katabagemu-Mataba: 90-83% similarity
# 119
# Katabagema - Katabagemu-Mataba: 90-83% similarity
# 123
# Karushuga? - Bushoga-Karuhuga: 71-88% similarity
# 813
# Rukatsi - Rukatsa-Rukatsa: 86-86% similarity
# 1120
# Gitda - Gitabura-Gitwa: 80-80% similarity
# 1244
# Biteteri - Buteteri-Butete: 88-83% similarity
# 1378
# Karushuga? - Bushoga-Karuhuga: 71-88% similarity
